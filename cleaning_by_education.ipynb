# %%
 # Dependencies
import pandas as pd

# %%
# Name of the CSV file
path = "data/Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics_2018.csv"
# Use encoding to read the CSV in pandas
table =pd.read_csv(path, encoding="UTF-8")
# Preview of the DataFrame
table
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages  \
# 0                                                 NaN
# 1                                      Characteristic
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                         Age and sex
# 6                            Total, 16 years and over
# 7                                      16 to 24 years
# 8                                      25 to 54 years
# 9                                      25 to 34 years
# 10                                     35 to 44 years
# 11                                     45 to 54 years
# 12                                  55 years and over
# 13                                     55 to 64 years
# 14                                  65 years and over
# 15                                                NaN
# 16                             Men, 16 years and over
# 17                                     16 to 24 years
# 18                                     25 to 54 years
# 19                                  55 years and over
# 20                                                NaN
# 21                           Women, 16 years and over
# 22                                     16 to 24 years
# 23                                     25 to 54 years
# 24                                  55 years and over
# 25                                                NaN
# 26              Race and Hispanic or Latino ethnicity
# 27                           White, 16 years and over
# 28                                                Men
# 29                                              Women
# ..                                                ...
# 47                       Bachelor's degree and higher
# 48                             Bachelor's degree only
# 49                                 Advanced degree(4)
# 50                                                NaN
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
# 55                            Some college, no degree
# 56                                   Associate degree
# 57                       Bachelor's degree and higher
# 58                             Bachelor's degree only
# 59                                 Advanced degree(4)
# 60                                                NaN
# 61                           Women, 25 years and over
# 62                    Less than a high school diploma
# 63               High school graduates, no college(3)
# 64                   Some college or associate degree
# 65                            Some college, no degree
# 66                                   Associate degree
# 67                       Bachelor's degree and higher
# 68                             Bachelor's degree only
# 69                                 Advanced degree(4)
# 70                                                NaN
# 71                                         Footnotes:
# 72  (1) A person may have more than one certificat...
# 73  (2) Persons with a license may also have a cer...
# 74  (3) Includes persons with a high school diplom...
# 75  (4) Includes persons with master's, profession...
# 76  NOTE: Certifications are issued by a non-gover...
#
#                                            Unnamed: 1              Unnamed: 2  \
# 0                                                 NaN                     NaN
# 1   Full-time\nwage and\nsalary\nworkers (in\nthou...  Median weekly earnings
# 2                                                 NaN                   Total
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                             115,567                    $886
# 7                                              10,428                     548
# 8                                              80,891                     917
# 9                                              28,874                     808
# 10                                             26,452                     986
# 11                                             25,565                   1,002
# 12                                             24,247                     985
# 13                                             19,585                     994
# 14                                              4,662                     944
# 15                                                NaN                     NaN
# 16                                             64,142                     973
# 17                                              5,818                     575
# 18                                             45,061                   1,004
# 19                                             13,263                   1,127
# 20                                                NaN                     NaN
# 21                                             51,425                     789
# 22                                              4,611                     522
# 23                                             35,830                     825
# 24                                             10,984                     845
# 25                                                NaN                     NaN
# 26                                                NaN                     NaN
# 27                                             88,953                     916
# 28                                             50,570                   1,002
# 29                                             38,384                     817
# ..                                                ...                     ...
# 47                                             44,427                   1,324
# 48                                             27,660                   1,198
# 49                                             16,767                   1,521
# 50                                                NaN                     NaN
# 51                                             58,324                   1,026
# 52                                              4,761                     607
# 53                                             16,105                     819
# 54                                             14,721                     951
# 55                                              8,892                     918
# 56                                              5,829                     994
# 57                                             22,738                   1,524
# 58                                             14,451                   1,384
# 59                                              8,287                   1,774
# 60                                                NaN                     NaN
# 61                                             46,814                     830
# 62                                              2,238                     469
# 63                                             10,132                     616
# 64                                             12,755                     717
# 65                                              6,995                     694
# 66                                              5,760                     746
# 67                                             21,689                   1,145
# 68                                             13,208                   1,041
# 69                                              8,480                   1,323
# 70                                                NaN                     NaN
# 71                                                NaN                     NaN
# 72                                                NaN                     NaN
# 73                                                NaN                     NaN
# 74                                                NaN                     NaN
# 75                                                NaN                     NaN
# 76                                                NaN                     NaN
#
#                             Unnamed: 3  \
# 0                                  NaN
# 1                                  NaN
# 2   With a certification or license(1)
# 3                                Total
# 4                                  NaN
# 5                                  NaN
# 6                               $1,106
# 7                                  634
# 8                                1,110
# 9                                  950
# 10                               1,189
# 11                               1,209
# 12                               1,205
# 13                               1,205
# 14                               1,207
# 15                                 NaN
# 16                               1,231
# 17                                 687
# 18                               1,236
# 19                               1,347
# 20                                 NaN
# 21                                 990
# 22                                 607
# 23                                 996
# 24                               1,118
# 25                                 NaN
# 26                                 NaN
# 27                               1,133
# 28                               1,252
# 29                               1,017
# ..                                 ...
# 47                               1,356
# 48                               1,212
# 49                               1,499
# 50                                 NaN
# 51                               1,256
# 52                                 750
# 53                                 983
# 54                               1,056
# 55                               1,027
# 56                               1,085
# 57                               1,590
# 58                               1,425
# 59                               1,800
# 60                                 NaN
# 61                               1,015
# 62                                 491
# 63                                 621
# 64                                 757
# 65                                 698
# 66                                 808
# 67                               1,204
# 68                               1,089
# 69                               1,345
# 70                                 NaN
# 71                                 NaN
# 72                                 NaN
# 73                                 NaN
# 74                                 NaN
# 75                                 NaN
# 76                                 NaN
#
#                                 Unnamed: 4          Unnamed: 5  \
# 0                                      NaN                 NaN
# 1                                      NaN                 NaN
# 2                                      NaN                 NaN
# 3   With a\ncertification,\nbut no license  With a\nlicense(2)
# 4                                      NaN                 NaN
# 5                                      NaN                 NaN
# 6                                   $1,196              $1,093
# 7                                      597                 638
# 8                                    1,206               1,098
# 9                                    1,031                 941
# 10                                   1,322               1,176
# 11                                   1,343               1,198
# 12                                   1,326               1,195
# 13                                   1,362               1,191
# 14                                   1,169               1,210
# 15                                     NaN                 NaN
# 16                                   1,283               1,226
# 17                                     631                 693
# 18                                   1,269               1,232
# 19                                   1,479               1,333
# 20                                     NaN                 NaN
# 21                                   1,071                 985
# 22                                     557                 610
# 23                                   1,100                 989
# 24                                   1,138               1,115
# 25                                     NaN                 NaN
# 26                                     NaN                 NaN
# 27                                   1,202               1,127
# 28                                   1,299               1,248
# 29                                   1,078               1,012
# ..                                     ...                 ...
# 47                                   1,553               1,339
# 48                                   1,442               1,181
# 49                                   1,766               1,479
# 50                                     NaN                 NaN
# 51                                   1,327               1,250
# 52                                       –                 755
# 53                                     988                 983
# 54                                   1,114               1,047
# 55                                   1,150               1,008
# 56                                   1,061               1,089
# 57                                   1,734               1,572
# 58                                   1,581               1,397
# 59                                   1,894               1,774
# 60                                     NaN                 NaN
# 61                                   1,108               1,009
# 62                                       –                 494
# 63                                     695                 616
# 64                                     772                 755
# 65                                     762                 690
# 66                                     791                 809
# 67                                   1,372               1,190
# 68                                   1,273               1,074
# 69                                   1,546               1,335
# 70                                     NaN                 NaN
# 71                                     NaN                 NaN
# 72                                     NaN                 NaN
# 73                                     NaN                 NaN
# 74                                     NaN                 NaN
# 75                                     NaN                 NaN
# 76                                     NaN                 NaN
#
#                               Unnamed: 6
# 0                                    NaN
# 1                                    NaN
# 2   Without a\ncertification or\nlicense
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                   $818
# 7                                    532
# 8                                    858
# 9                                    765
# 10                                   913
# 11                                   928
# 12                                   916
# 13                                   928
# 14                                   849
# 15                                   NaN
# 16                                   907
# 17                                   560
# 18                                   943
# 19                                 1,048
# 20                                   NaN
# 21                                   726
# 22                                   512
# 23                                   754
# 24                                   770
# 25                                   NaN
# 26                                   NaN
# 27                                   847
# 28                                   935
# 29                                   743
# ..                                   ...
# 47                                 1,284
# 48                                 1,190
# 49                                 1,538
# 50                                   NaN
# 51                                   966
# 52                                   600
# 53                                   799
# 54                                   916
# 55                                   892
# 56                                   958
# 57                                 1,485
# 58                                 1,372
# 59                                 1,770
# 60                                   NaN
# 61                                   758
# 62                                   468
# 63                                   615
# 64                                   702
# 65                                   693
# 66                                   716
# 67                                 1,092
# 68                                 1,019
# 69                                 1,274
# 70                                   NaN
# 71                                   NaN
# 72                                   NaN
# 73                                   NaN
# 74                                   NaN
# 75                                   NaN
# 76                                   NaN
#
# [77 rows x 7 columns]

# %%
list(table.columns)
# Out:
# ['HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6']

# %%
#Rename the column names
table = table.drop(columns =['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4','Unnamed: 5','Unnamed: 6'])
table.head()
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages  \
# 0                                                NaN
# 1                                     Characteristic
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                Unnamed: 2
# 0                     NaN
# 1  Median weekly earnings
# 2                   Total
# 3                     NaN
# 4                     NaN

# %%
table = table.drop(table.index[range(0,50)], axis=0)
table.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages  \
# 50                                                NaN
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
#
#    Unnamed: 2
# 50        NaN
# 51      1,026
# 52        607
# 53        819
# 54        951

# %%
table.reset_index(drop =True)
table.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages  \
# 50                                                NaN
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
#
#    Unnamed: 2
# 50        NaN
# 51      1,026
# 52        607
# 53        819
# 54        951

# %%
table = table.drop(table.index[[0,10,20,21,22,23,24,25,26]])
table.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages  \
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
# 55                            Some college, no degree
#
#    Unnamed: 2
# 51      1,026
# 52        607
# 53        819
# 54        951
# 55        918

# %%
#Rename the column names
table = table.rename(columns ={'HOUSEHOLD DATA\nANNUAL AVERAGES\n54. Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2018 annual averages': 'By education',
                               'Unnamed: 2': 'Median weekly earnings in 2018'})
table = table.reset_index(drop =True)
table.head()
# Out:
#                            By education Median weekly earnings in 2018
# 0                Men, 25 years and over                          1,026
# 1       Less than a high school diploma                            607
# 2  High school graduates, no college(3)                            819
# 3      Some college or associate degree                            951
# 4               Some college, no degree                            918

# %%
# Name of the CSV file
path_2017 = "data/Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics_2017.csv"
# Use encoding to read the CSV in pandas
table_2017 =pd.read_csv(path_2017, encoding="UTF-8")
# Preview of the DataFrame
table_2017.head()
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2017 annual averages  \
# 0                                                NaN
# 1                                     Characteristic
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 1              Unnamed: 2  \
# 0                                                NaN                     NaN
# 1  Full-time\nwage and\nsalary\nworkers (in\nthou...  Median weekly earnings
# 2                                                NaN                   Total
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#                            Unnamed: 3                              Unnamed: 4  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2  With a certification or license(1)                                     NaN
# 3                               Total  With a\ncertification,\nbut no license
# 4                                 NaN                                     NaN
#
#            Unnamed: 5                            Unnamed: 6
# 0                 NaN                                   NaN
# 1                 NaN                                   NaN
# 2                 NaN  Without a\ncertification or\nlicense
# 3  With a\nlicense(2)                                   NaN
# 4                 NaN                                   NaN

# %%
#Rename the column names
table_2017 = table_2017.drop(columns =['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4','Unnamed: 5','Unnamed: 6'])
table_2017.head()
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2017 annual averages  \
# 0                                                NaN
# 1                                     Characteristic
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                Unnamed: 2
# 0                     NaN
# 1  Median weekly earnings
# 2                   Total
# 3                     NaN
# 4                     NaN

# %%
table_2017 = table_2017.drop(table_2017.index[range(0,50)], axis=0)
table_2017.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2017 annual averages  \
# 50                                                NaN
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
#
#    Unnamed: 2
# 50        NaN
# 51        996
# 52        584
# 53        797
# 54        917

# %%
table_2017.reset_index(drop =True)
table_2017.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2017 annual averages  \
# 50                                                NaN
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
#
#    Unnamed: 2
# 50        NaN
# 51        996
# 52        584
# 53        797
# 54        917

# %%
table_2017 = table_2017.drop(table_2017.index[[0,10,20,21,22,23,24,25,26]])
table_2017.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2017 annual averages  \
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
# 55                            Some college, no degree
#
#    Unnamed: 2
# 51        996
# 52        584
# 53        797
# 54        917
# 55        886

# %%
#Rename the column names
table_2017 = table_2017.rename(columns ={'HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2017 annual averages': 'By education',
                               'Unnamed: 2': 'Median weekly earnings in 2017'})
table_2017 = table_2017.reset_index(drop =True)
table_2017.head()
# Out:
#                            By education Median weekly earnings in 2017
# 0                Men, 25 years and over                            996
# 1       Less than a high school diploma                            584
# 2  High school graduates, no college(3)                            797
# 3      Some college or associate degree                            917
# 4               Some college, no degree                            886

# %%
# Name of the CSV file
path_2016 = "data/Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics_2016.csv"
# Use encoding to read the CSV in pandas
table_2016 =pd.read_csv(path_2016, encoding="UTF-8")
# Preview of the DataFrame
table_2016.head()
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2016 annual averages  \
# 0                                                NaN
# 1                                     Characteristic
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 1              Unnamed: 2  \
# 0                                                NaN                     NaN
# 1  Full-time\nwage and\nsalary\nworkers (in\nthou...  Median weekly earnings
# 2                                                NaN                   Total
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#                            Unnamed: 3                              Unnamed: 4  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2  With a certification or license(1)                                     NaN
# 3                               Total  With a\ncertification,\nbut no license
# 4                                 NaN                                     NaN
#
#            Unnamed: 5                            Unnamed: 6
# 0                 NaN                                   NaN
# 1                 NaN                                   NaN
# 2                 NaN  Without a\ncertification or\nlicense
# 3  With a\nlicense(2)                                   NaN
# 4                 NaN                                   NaN

# %%
#Rename the column names
table_2016 = table_2016.drop(columns =['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4','Unnamed: 5','Unnamed: 6'])
table_2016.head()
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2016 annual averages  \
# 0                                                NaN
# 1                                     Characteristic
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                Unnamed: 2
# 0                     NaN
# 1  Median weekly earnings
# 2                   Total
# 3                     NaN
# 4                     NaN

# %%
table_2016 = table_2016.drop(table_2016.index[range(0,50)], axis=0)
table_2016.head()
# Out:
#    HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2016 annual averages  \
# 50                                                NaN
# 51                             Men, 25 years and over
# 52                    Less than a high school diploma
# 53               High school graduates, no college(3)
# 54                   Some college or associate degree
#
#    Unnamed: 2
# 50        NaN
# 51        969
# 52        551
# 53        769
# 54        896

# %%
table_2016 = table_2016.reset_index(drop = True)
table_2016 = table_2016.drop(table_2016.index[[0,10,20,21,22,23,24,25,26]])
table_2016.head()
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2016 annual averages  \
# 1                             Men, 25 years and over
# 2                    Less than a high school diploma
# 3               High school graduates, no college(3)
# 4                   Some college or associate degree
# 5                            Some college, no degree
#
#   Unnamed: 2
# 1        969
# 2        551
# 3        769
# 4        896
# 5        861

# %%
#Rename the column names
table_2016 = table_2016.rename(columns ={'HOUSEHOLD DATA\nANNUAL AVERAGES\n54.  Median weekly earnings of full-time wage and salary workers by certification and licensing status and selected characteristics, 2016 annual averages': 'By education',
                               'Unnamed: 2': 'Median weekly earnings in 2016'})
table_2016 = table_2016.reset_index(drop =True)
table_2016.head()
# Out:
#                            By education Median weekly earnings in 2016
# 0                Men, 25 years and over                            969
# 1       Less than a high school diploma                            551
# 2  High school graduates, no college(3)                            769
# 3      Some college or associate degree                            896
# 4               Some college, no degree                            861

# %%
table.to_csv(r'data\by_education_2018.csv', index=False)
table_2017.to_csv(r'data\by_education_2017.csv', index=False)
table_2016.to_csv(r'data\by_education_2016.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-20-b8707139cd92> in <module>
# ----> 1 table.to_csv(r'data\by_education_2018.csv', index=False)
#       2 table_2017.to_csv(r'data\by_education_2017.csv', index=False)
#       3 table_2016.to_csv(r'data\by_education_2016.csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'data\\by_education_2018.csv'
