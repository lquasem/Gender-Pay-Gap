# %%
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import MetaData
from sqlalchemy.orm import mapper
from config import password

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

import pandas as pd

# %%
path = "cleaned_data/gender_race.csv"
pay_gap_by_gender_table = pd.read_csv(path, encoding="UTF-8")
pay_gap_by_gender_table.index.name = 'id'
pay_gap_by_gender_table.head()
# Out:
#    categoryindex category  total_workers  median_weekly_earnings  year
# id
# 0          Total    Total         113272                     860  2017
# 1      Total_Men      Men          62980                     941  2017
# 2    Total_Women    Women          50291                     770  2017
# 3    White_Total    White          87730                     890  2017
# 4      White_Men      Men          50003                     971  2017

# %%
engine = create_engine('postgresql://postgres:'+ password + '@localhost:5432/gender_pay_gap')

# %%
#engine.table_names()
metadata = MetaData()
metadata.reflect(bind=engine)
print(metadata.tables)
# Out:
# immutabledict({'by_race': Table('by_race', MetaData(bind=None), Column('id', INTEGER(), table=<by_race>, primary_key=True, nullable=False), Column('household_data', VARCHAR(length=28), table=<by_race>), Column('total_workers_2017', INTEGER(), table=<by_race>), Column('total_workers_2018', INTEGER(), table=<by_race>), Column('median_weekly_earnings_2017', INTEGER(), table=<by_race>), Column('median_weekly_earnings_2018', INTEGER(), table=<by_race>), schema=None), 'pay_gap_by_race': Table('pay_gap_by_race', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_race>, primary_key=True, nullable=False), Column('categoryindex', VARCHAR(length=50), table=<pay_gap_by_race>, nullable=False), Column('category', VARCHAR(length=50), table=<pay_gap_by_race>), Column('total_workers', INTEGER(), table=<pay_gap_by_race>), Column('median_weekly_earnings', INTEGER(), table=<pay_gap_by_race>), Column('year', INTEGER(), table=<pay_gap_by_race>), schema=None), 'pay_gap_by_education': Table('pay_gap_by_education', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_education>, primary_key=True, nullable=False), Column('education_level', VARCHAR(length=50), table=<pay_gap_by_education>, nullable=False), Column('median_weekly_earnings_in_2018', INTEGER(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2017', INTEGER(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2016', INTEGER(), table=<pay_gap_by_education>), Column('gender', VARCHAR(length=50), table=<pay_gap_by_education>), schema=None), 'pay_gap_by_country': Table('pay_gap_by_country', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_country>, primary_key=True, nullable=False), Column('country', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('latitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('longitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('sex', VARCHAR(length=20), table=<pay_gap_by_country>, nullable=False), Column('occupation', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('currency', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('survey', TEXT(), table=<pay_gap_by_country>), Column('type_of_source', TEXT(), table=<pay_gap_by_country>), Column('year_2016_earnings', INTEGER(), table=<pay_gap_by_country>), schema=None)})

# %%
pay_gap_by_gender_table.to_sql(name='pay_gap_by_race', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UniqueViolation: duplicate key value violates unique constraint "pay_gap_by_race_pkey"
# DETAIL:  Key (id)=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-5-425f3985e81c> in <module>
# ----> 1 pay_gap_by_gender_table.to_sql(name='pay_gap_by_race', con=engine, if_exists='append', index=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     723             extras.execute_batch(cursor, statement, parameters)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#     727     @util.memoized_instancemethod
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pay_gap_by_race_pkey"
# DETAIL:  Key (id)=(0) already exists.
#
# [SQL: INSERT INTO pay_gap_by_race (id, categoryindex, category, total_workers, median_weekly_earnings, year) VALUES (%(id)s, %(categoryindex)s, %(category)s, %(total_workers)s, %(median_weekly_earnings)s, %(year)s)]
# [parameters: ({'id': 0, 'categoryindex': 'Total', 'category': 'Total', 'total_workers': 113272, 'median_weekly_earnings': 860, 'year': 2017}, {'id': 1, 'categoryindex': 'Total_Men', 'category': 'Men', 'total_workers': 62980, 'median_weekly_earnings': 941, 'year': 2017}, {'id': 2, 'categoryindex': 'Total_Women', 'category': 'Women', 'total_workers': 50291, 'median_weekly_earnings': 770, 'year': 2017}, {'id': 3, 'categoryindex': 'White_Total', 'category': 'White', 'total_workers': 87730, 'median_weekly_earnings': 890, 'year': 2017}, {'id': 4, 'categoryindex': 'White_Men', 'category': 'Men', 'total_workers': 50003, 'median_weekly_earnings': 971, 'year': 2017}, {'id': 5, 'categoryindex': 'White_Women', 'category': 'Women', 'total_workers': 37727, 'median_weekly_earnings': 795, 'year': 2017}, {'id': 6, 'categoryindex': 'AfroAmerican_Total', 'category': 'Black or African American', 'total_workers': 14521, 'median_weekly_earnings': 682, 'year': 2017}, {'id': 7, 'categoryindex': 'AfroAmerican_Men', 'category': 'Men', 'total_workers': 6928, 'median_weekly_earnings': 710, 'year': 2017}  ... displaying 10 of 60 total bound parameter sets ...  {'id': 58, 'categoryindex': 'Hispanic_Men', 'category': 'Men', 'total_workers': 11666, 'median_weekly_earnings': 663, 'year': 2016}, {'id': 59, 'categoryindex': 'Hispanic_Women', 'category': 'Women', 'total_workers': 7284, 'median_weekly_earnings': 586, 'year': 2016})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %% [markdown]
# # Loading data for gender_pay_gap_byCoutry

# %%
global_data= pd.read_csv("cleaned_data/by_global.csv")
coords_data= pd.read_csv("cleaned_data/cords.csv")

# %%
global_data.head(5)
# Out:
#       Country           Sex                    Occupation  \
# 0     Albania    Male (Sex)  Total (Occupation (ISCO-08))
# 1     Albania  Female (Sex)  Total (Occupation (ISCO-08))
# 2     Armenia    Male (Sex)  Total (Occupation (ISCO-08))
# 3     Armenia  Female (Sex)  Total (Occupation (ISCO-08))
# 4  Azerbaijan    Male (Sex)  Total (Occupation (ISCO-08))
#
#                   Currency                               Survey  \
# 0  U.S. dollars (Currency)      General Directorate of Taxation
# 1  U.S. dollars (Currency)      General Directorate of Taxation
# 2  U.S. dollars (Currency)        Household Labour Force Survey
# 3  U.S. dollars (Currency)        Household Labour Force Survey
# 4  U.S. dollars (Currency)  Labour-related establishment survey
#
#          Type_of_Source  Year_2016
# 0     Insurance records        403
# 1     Insurance records        357
# 2   Labour force survey        249
# 3   Labour force survey        166
# 4  Establishment survey        395

# %%
coords_data.head(5)
# Out:
#           Country           Capital Latitude Longitude
# 0     Afghanistan             Kabul  34°28'N   69°11'E
# 1         Albania            Tirane  41°18'N   19°49'E
# 2         Algeria           Algiers  36°42'N   03°08'E
# 3  American Samoa         Pago Pago  14°16'S  170°43'W
# 4         Andorra  Andorra la Vella  42°31'N   01°32'E

# %%
# Merge two dataframes using an inner join
global_coords_merged_table = pd.merge(coords_data, global_data ,on="Country")
global_coords_merged_table.index.name = 'id'

global_coords_merged_table.head(100)
# Out:
#                    Country                            Capital Latitude  \
# id
# 0                  Albania                             Tirane  41°18'N
# 1                  Albania                             Tirane  41°18'N
# 2                  Armenia                            Yerevan  40°10'N
# 3                  Armenia                            Yerevan  40°10'N
# 4               Azerbaijan                               Baku  40°29'N
# 5               Azerbaijan                               Baku  40°29'N
# 6               Bangladesh                              Dhaka  23°43'N
# 7               Bangladesh                              Dhaka  23°43'N
# 8                  Belgium                           Brussels  50°51'N
# 9                  Belgium                           Brussels  50°51'N
# 10                  Belize                           Belmopan  17°18'N
# 11                  Belize                           Belmopan  17°18'N
# 12                 Bolivia  La Paz (adm.)/sucre (legislative)  16°20'S
# 13                 Bolivia  La Paz (adm.)/sucre (legislative)  16°20'S
# 14  Bosnia and Herzegovina                           Sarajevo  43°52'N
# 15  Bosnia and Herzegovina                           Sarajevo  43°52'N
# 16                  Brazil                           Brasilia  15°47'S
# 17                  Brazil                           Brasilia  15°47'S
# 18                Cambodia                         Phnom Penh  11°33'N
# 19                Cambodia                         Phnom Penh  11°33'N
# 20              Costa Rica                           San Jose  09°55'N
# 21              Costa Rica                           San Jose  09°55'N
# 22              Costa Rica                           San Jose  09°55'N
# 23              Costa Rica                           San Jose  09°55'N
# 24          Czech Republic                             Prague  50°05'N
# 25          Czech Republic                             Prague  50°05'N
# 26                 Ecuador                              Quito  00°15'S
# 27                 Ecuador                              Quito  00°15'S
# 28                   Egypt                              Cairo  30°01'N
# 29                   Egypt                              Cairo  30°01'N
# ..                     ...                                ...      ...
# 50                    Mali                             Bamako  12°34'N
# 51                    Mali                             Bamako  12°34'N
# 52                  Mexico                             Mexico  19°20'N
# 53                  Mexico                             Mexico  19°20'N
# 54                Pakistan                          Islamabad  33°40'N
# 55                Pakistan                          Islamabad  33°40'N
# 56                  Panama                             Panama  09°00'N
# 57                  Panama                             Panama  09°00'N
# 58                Paraguay                           Asuncion  25°10'S
# 59                Paraguay                           Asuncion  25°10'S
# 60                  Poland                             Warsaw  52°13'N
# 61                  Poland                             Warsaw  52°13'N
# 62                Portugal                             Lisbon  38°42'N
# 63                Portugal                             Lisbon  38°42'N
# 64                 Romania                          Bucuresti  44°27'N
# 65                 Romania                          Bucuresti  44°27'N
# 66                Slovakia                         Bratislava  48°10'N
# 67                Slovakia                         Bratislava  48°10'N
# 68                Slovenia                          Ljubljana  46°04'N
# 69                Slovenia                          Ljubljana  46°04'N
# 70                   Spain                             Madrid  40°25'N
# 71                   Spain                             Madrid  40°25'N
# 72                Thailand                            Bangkok  13°45'N
# 73                Thailand                            Bangkok  13°45'N
# 74                 Ukraine                         Kiev (Rus)  50°30'N
# 75                 Ukraine                         Kiev (Rus)  50°30'N
# 76                 Uruguay                         Montevideo  34°50'S
# 77                 Uruguay                         Montevideo  34°50'S
# 78                Viet Nam                              Hanoi  21°05'N
# 79                Viet Nam                              Hanoi  21°05'N
#
#    Longitude           Sex                    Occupation  \
# id
# 0    19°49'E    Male (Sex)  Total (Occupation (ISCO-08))
# 1    19°49'E  Female (Sex)  Total (Occupation (ISCO-08))
# 2    44°31'E    Male (Sex)  Total (Occupation (ISCO-08))
# 3    44°31'E  Female (Sex)  Total (Occupation (ISCO-08))
# 4    49°56'E    Male (Sex)  Total (Occupation (ISCO-08))
# 5    49°56'E  Female (Sex)  Total (Occupation (ISCO-08))
# 6    90°26'E    Male (Sex)  Total (Occupation (ISCO-08))
# 7    90°26'E  Female (Sex)  Total (Occupation (ISCO-08))
# 8    04°21'E    Male (Sex)  Total (Occupation (ISCO-08))
# 9    04°21'E  Female (Sex)  Total (Occupation (ISCO-08))
# 10   88°30'W    Male (Sex)  Total (Occupation (ISCO-08))
# 11   88°30'W  Female (Sex)  Total (Occupation (ISCO-08))
# 12   68°10'W    Male (Sex)  Total (Occupation (ISCO-08))
# 13   68°10'W  Female (Sex)  Total (Occupation (ISCO-08))
# 14   18°26'E    Male (Sex)  Total (Occupation (ISCO-08))
# 15   18°26'E  Female (Sex)  Total (Occupation (ISCO-08))
# 16   47°55'W    Male (Sex)  Total (Occupation (ISCO-08))
# 17   47°55'W  Female (Sex)  Total (Occupation (ISCO-08))
# 18  104°55'E    Male (Sex)  Total (Occupation (ISCO-08))
# 19  104°55'E  Female (Sex)  Total (Occupation (ISCO-08))
# 20   84°02'W    Male (Sex)  Total (Occupation (ISCO-08))
# 21   84°02'W  Female (Sex)  Total (Occupation (ISCO-08))
# 22   84°02'W    Male (Sex)  Total (Occupation (ISCO-08))
# 23   84°02'W  Female (Sex)  Total (Occupation (ISCO-08))
# 24   14°22'E    Male (Sex)  Total (Occupation (ISCO-08))
# 25   14°22'E  Female (Sex)  Total (Occupation (ISCO-08))
# 26   78°35'W    Male (Sex)  Total (Occupation (ISCO-08))
# 27   78°35'W  Female (Sex)  Total (Occupation (ISCO-08))
# 28   31°14'E    Male (Sex)  Total (Occupation (ISCO-08))
# 29   31°14'E  Female (Sex)  Total (Occupation (ISCO-08))
# ..       ...           ...                           ...
# 50   07°55'W    Male (Sex)  Total (Occupation (ISCO-08))
# 51   07°55'W  Female (Sex)  Total (Occupation (ISCO-08))
# 52   99°10'W    Male (Sex)  Total (Occupation (ISCO-08))
# 53   99°10'W  Female (Sex)  Total (Occupation (ISCO-08))
# 54   73°10'E    Male (Sex)  Total (Occupation (ISCO-08))
# 55   73°10'E  Female (Sex)  Total (Occupation (ISCO-08))
# 56   79°25'W    Male (Sex)  Total (Occupation (ISCO-08))
# 57   79°25'W  Female (Sex)  Total (Occupation (ISCO-08))
# 58   57°30'W    Male (Sex)  Total (Occupation (ISCO-08))
# 59   57°30'W  Female (Sex)  Total (Occupation (ISCO-08))
# 60   21°00'E    Male (Sex)  Total (Occupation (ISCO-08))
# 61   21°00'E  Female (Sex)  Total (Occupation (ISCO-08))
# 62   09°10'W    Male (Sex)  Total (Occupation (ISCO-08))
# 63   09°10'W  Female (Sex)  Total (Occupation (ISCO-08))
# 64   26°10'E    Male (Sex)  Total (Occupation (ISCO-08))
# 65   26°10'E  Female (Sex)  Total (Occupation (ISCO-08))
# 66   17°07'E    Male (Sex)  Total (Occupation (ISCO-08))
# 67   17°07'E  Female (Sex)  Total (Occupation (ISCO-08))
# 68   14°33'E    Male (Sex)  Total (Occupation (ISCO-08))
# 69   14°33'E  Female (Sex)  Total (Occupation (ISCO-08))
# 70   03°45'W    Male (Sex)  Total (Occupation (ISCO-08))
# 71   03°45'W  Female (Sex)  Total (Occupation (ISCO-08))
# 72  100°35'E    Male (Sex)  Total (Occupation (ISCO-08))
# 73  100°35'E  Female (Sex)  Total (Occupation (ISCO-08))
# 74   30°28'E    Male (Sex)  Total (Occupation (ISCO-08))
# 75   30°28'E  Female (Sex)  Total (Occupation (ISCO-08))
# 76   56°11'W    Male (Sex)  Total (Occupation (ISCO-08))
# 77   56°11'W  Female (Sex)  Total (Occupation (ISCO-08))
# 78  105°55'E    Male (Sex)  Total (Occupation (ISCO-08))
# 79  105°55'E  Female (Sex)  Total (Occupation (ISCO-08))
#
#                    Currency  \
# id
# 0   U.S. dollars (Currency)
# 1   U.S. dollars (Currency)
# 2   U.S. dollars (Currency)
# 3   U.S. dollars (Currency)
# 4   U.S. dollars (Currency)
# 5   U.S. dollars (Currency)
# 6   U.S. dollars (Currency)
# 7   U.S. dollars (Currency)
# 8   U.S. dollars (Currency)
# 9   U.S. dollars (Currency)
# 10  U.S. dollars (Currency)
# 11  U.S. dollars (Currency)
# 12  U.S. dollars (Currency)
# 13  U.S. dollars (Currency)
# 14  U.S. dollars (Currency)
# 15  U.S. dollars (Currency)
# 16  U.S. dollars (Currency)
# 17  U.S. dollars (Currency)
# 18  U.S. dollars (Currency)
# 19  U.S. dollars (Currency)
# 20  U.S. dollars (Currency)
# 21  U.S. dollars (Currency)
# 22  U.S. dollars (Currency)
# 23  U.S. dollars (Currency)
# 24  U.S. dollars (Currency)
# 25  U.S. dollars (Currency)
# 26  U.S. dollars (Currency)
# 27  U.S. dollars (Currency)
# 28  U.S. dollars (Currency)
# 29  U.S. dollars (Currency)
# ..                      ...
# 50  U.S. dollars (Currency)
# 51  U.S. dollars (Currency)
# 52  U.S. dollars (Currency)
# 53  U.S. dollars (Currency)
# 54  U.S. dollars (Currency)
# 55  U.S. dollars (Currency)
# 56  U.S. dollars (Currency)
# 57  U.S. dollars (Currency)
# 58  U.S. dollars (Currency)
# 59  U.S. dollars (Currency)
# 60  U.S. dollars (Currency)
# 61  U.S. dollars (Currency)
# 62  U.S. dollars (Currency)
# 63  U.S. dollars (Currency)
# 64  U.S. dollars (Currency)
# 65  U.S. dollars (Currency)
# 66  U.S. dollars (Currency)
# 67  U.S. dollars (Currency)
# 68  U.S. dollars (Currency)
# 69  U.S. dollars (Currency)
# 70  U.S. dollars (Currency)
# 71  U.S. dollars (Currency)
# 72  U.S. dollars (Currency)
# 73  U.S. dollars (Currency)
# 74  U.S. dollars (Currency)
# 75  U.S. dollars (Currency)
# 76  U.S. dollars (Currency)
# 77  U.S. dollars (Currency)
# 78  U.S. dollars (Currency)
# 79  U.S. dollars (Currency)
#
#                                                Survey  \
# id
# 0                     General Directorate of Taxation
# 1                     General Directorate of Taxation
# 2                       Household Labour Force Survey
# 3                       Household Labour Force Survey
# 4                 Labour-related establishment survey
# 5                 Labour-related establishment survey
# 6                                 Labour Force Survey
# 7                                 Labour Force Survey
# 8                        Structure of Earnings Survey
# 9                        Structure of Earnings Survey
# 10                                Labour force survey
# 11                                Labour force survey
# 12                       Continuous Employment Survey
# 13                       Continuous Employment Survey
# 14                                Labour Force Survey
# 15                                Labour Force Survey
# 16        Continuous National Household Sample Survey
# 17        Continuous National Household Sample Survey
# 18                    Household Socio-Economic Survey
# 19                    Household Socio-Economic Survey
# 20                          National Household Survey
# 21                          National Household Survey
# 22                    National Business Survey (ENAE)
# 23                    National Business Survey (ENAE)
# 24                    Survey on Structure of Earnings
# 25                    Survey on Structure of Earnings
# 26  National Survey on Employment, Unemployment an...
# 27  National Survey on Employment, Unemployment an...
# 28                         Labour force sample survey
# 29                         Labour force sample survey
# ..                                                ...
# 50              Continous Household Employment Survey
# 51              Continous Household Employment Survey
# 52          National Occupation and Employment Survey
# 53          National Occupation and Employment Survey
# 54                                Labour Force Survey
# 55                                Labour Force Survey
# 56                               Labour Market Survey
# 57                               Labour Market Survey
# 58                         Continous Household Survey
# 59                         Continous Household Survey
# 60                       Structure of Earnings Survey
# 61                       Structure of Earnings Survey
# 62                                  Employment Survey
# 63                                  Employment Survey
# 64                                 Labour cost survey
# 65                                 Labour cost survey
# 66                Annual Structure of Earnings Survey
# 67                Annual Structure of Earnings Survey
# 68                      Structure of earnings records
# 69                      Structure of earnings records
# 70                                Labour Force Survey
# 71                                Labour Force Survey
# 72                                Labour force survey
# 73                                Labour force survey
# 74  Survey on wages of employees by gender, age, e...
# 75  Survey on wages of employees by gender, age, e...
# 76                         Continous Household Survey
# 77                         Continous Household Survey
# 78                                Labour force survey
# 79                                Labour force survey
#
#                                       Type_of_Source  Year_2016
# id
# 0                                  Insurance records        403
# 1                                  Insurance records        357
# 2                                Labour force survey        249
# 3                                Labour force survey        166
# 4                               Establishment survey        395
# 5                               Establishment survey        199
# 6                                Labour force survey        167
# 7                                Labour force survey        154
# 8                               Establishment survey       3634
# 9                               Establishment survey       2901
# 10                               Labour force survey        586
# 11                               Labour force survey        566
# 12                               Labour force survey        483
# 13                               Labour force survey        364
# 14                               Labour force survey        441
# 15                               Labour force survey        386
# 16                            Other household survey        654
# 17                            Other household survey        516
# 18               Household income/expenditure survey        195
# 19               Household income/expenditure survey        167
# 20                            Other household survey        967
# 21                            Other household survey        868
# 22                              Establishment survey        939
# 23                              Establishment survey        929
# 24                              Establishment survey       1312
# 25                              Establishment survey       1036
# 26                               Labour force survey        499
# 27                               Labour force survey        496
# 28                               Labour force survey        225
# 29                               Labour force survey        182
# ..                                               ...        ...
# 50                               Labour force survey        129
# 51                               Labour force survey         83
# 52                               Labour force survey        329
# 53                               Labour force survey        280
# 54                               Labour force survey        151
# 55                               Labour force survey         93
# 56                               Labour force survey        809
# 57                               Labour force survey        795
# 58                            Other household survey        401
# 59                            Other household survey        326
# 60                              Establishment survey       1193
# 61                              Establishment survey       1007
# 62                               Labour force survey       1012
# 63                               Labour force survey        852
# 64                              Establishment survey        714
# 65                              Establishment survey        667
# 66                              Establishment survey       1291
# 67                              Establishment survey       1007
# 68  Other administrative records and related sources       1916
# 69  Other administrative records and related sources       1803
# 70                               Labour force survey       2296
# 71                               Labour force survey       1837
# 72                               Labour force survey        421
# 73                               Labour force survey        419
# 74                              Establishment survey        215
# 75                              Establishment survey        166
# 76                               Labour force survey        955
# 77                               Labour force survey        754
# 78                               Labour force survey        259
# 79                               Labour force survey        239
#
# [80 rows x 10 columns]

# %%
global_coords_merged_table = global_coords_merged_table.drop(['Capital'], axis=1)


global_coords_merged_table = global_coords_merged_table.rename(columns={"id": "id", 
                            "Country": "country",
                           "Latitude": "latitude",
                           "Longitude": "longitude",
                           "Sex": "sex",
                           "Occupation": "occupation",
                           "Currency": "currency",
                           "Survey": "survey",
                           "Type_of_Source": "type_of_source",
                           "Year_2016": "year_2016_earnings"})

# %%
global_coords_merged_table.to_csv("Global_coords.csv")
global_coords_merged_table.head(10)
# Out:
#        country latitude longitude           sex                    occupation  \
# id
# 0      Albania  41°18'N   19°49'E    Male (Sex)  Total (Occupation (ISCO-08))
# 1      Albania  41°18'N   19°49'E  Female (Sex)  Total (Occupation (ISCO-08))
# 2      Armenia  40°10'N   44°31'E    Male (Sex)  Total (Occupation (ISCO-08))
# 3      Armenia  40°10'N   44°31'E  Female (Sex)  Total (Occupation (ISCO-08))
# 4   Azerbaijan  40°29'N   49°56'E    Male (Sex)  Total (Occupation (ISCO-08))
# 5   Azerbaijan  40°29'N   49°56'E  Female (Sex)  Total (Occupation (ISCO-08))
# 6   Bangladesh  23°43'N   90°26'E    Male (Sex)  Total (Occupation (ISCO-08))
# 7   Bangladesh  23°43'N   90°26'E  Female (Sex)  Total (Occupation (ISCO-08))
# 8      Belgium  50°51'N   04°21'E    Male (Sex)  Total (Occupation (ISCO-08))
# 9      Belgium  50°51'N   04°21'E  Female (Sex)  Total (Occupation (ISCO-08))
#
#                    currency                               survey  \
# id
# 0   U.S. dollars (Currency)      General Directorate of Taxation
# 1   U.S. dollars (Currency)      General Directorate of Taxation
# 2   U.S. dollars (Currency)        Household Labour Force Survey
# 3   U.S. dollars (Currency)        Household Labour Force Survey
# 4   U.S. dollars (Currency)  Labour-related establishment survey
# 5   U.S. dollars (Currency)  Labour-related establishment survey
# 6   U.S. dollars (Currency)                  Labour Force Survey
# 7   U.S. dollars (Currency)                  Labour Force Survey
# 8   U.S. dollars (Currency)         Structure of Earnings Survey
# 9   U.S. dollars (Currency)         Structure of Earnings Survey
#
#           type_of_source  year_2016_earnings
# id
# 0      Insurance records                 403
# 1      Insurance records                 357
# 2    Labour force survey                 249
# 3    Labour force survey                 166
# 4   Establishment survey                 395
# 5   Establishment survey                 199
# 6    Labour force survey                 167
# 7    Labour force survey                 154
# 8   Establishment survey                3634
# 9   Establishment survey                2901

# %%
global_coords_merged_table.to_sql(name='pay_gap_by_country', con=engine, if_exists='append', index=True)

# %% [markdown]
# # Loading data for byEducation

# %%
path_by_education = "cleaned_data/by_education_2016-2018.csv"
pay_gap_by_education = pd.read_csv(path_by_education, encoding="UTF-8")
pay_gap_by_education.index.name = 'id'
pay_gap_by_education.head()
# Out:
#                             By education  Median weekly earnings in 2018  \
# id
# 0                 Men, 25 years and over                            1026
# 1        Less than a high school diploma                             607
# 2   High school graduates, no college(3)                             819
# 3       Some college or associate degree                             951
# 4                Some college, no degree                             918
#
#     Median weekly earnings in 2017  Median weekly earnings in 2016 Gender
# id
# 0                              996                             969   Male
# 1                              584                             551   Male
# 2                              797                             769   Male
# 3                              917                             896   Male
# 4                              886                             861   Male

# %%
pay_gap_by_education = pay_gap_by_education.rename(columns ={'By education': 'education_level',
                               'Median weekly earnings in 2018': 'median_weekly_earnings_in_2018',
                               'Median weekly earnings in 2017': 'median_weekly_earnings_in_2017',
                               'Median weekly earnings in 2016': 'median_weekly_earnings_in_2016',
                                                            'Gender':'gender'})
pay_gap_by_education.head()
# Out:
#                          education_level  median_weekly_earnings_in_2018  \
# id
# 0                 Men, 25 years and over                            1026
# 1        Less than a high school diploma                             607
# 2   High school graduates, no college(3)                             819
# 3       Some college or associate degree                             951
# 4                Some college, no degree                             918
#
#     median_weekly_earnings_in_2017  median_weekly_earnings_in_2016 gender
# id
# 0                              996                             969   Male
# 1                              584                             551   Male
# 2                              797                             769   Male
# 3                              917                             896   Male
# 4                              886                             861   Male

# %%
pay_gap_by_education.dtypes
# Out:
# education_level                   object
# median_weekly_earnings_in_2018     int64
# median_weekly_earnings_in_2017     int64
# median_weekly_earnings_in_2016     int64
# gender                            object
# dtype: object

# %%
 # Use pd.to_numeric() method to convert the datatype of the Amount column
pay_gap_by_education['median_weekly_earnings_in_2018'] = pd.to_numeric(pay_gap_by_education['median_weekly_earnings_in_2018'])

# %%
list(pay_gap_by_education.columns)
# Out:
# ['education_level',
#  'median_weekly_earnings_in_2018',
#  'median_weekly_earnings_in_2017',
#  'median_weekly_earnings_in_2016',
#  'gender']

# %%
#engine.table_names()
metadata = MetaData()
metadata.reflect(bind=engine)
print(metadata.tables)
# Out:
# immutabledict({'by_race': Table('by_race', MetaData(bind=None), Column('id', INTEGER(), table=<by_race>, primary_key=True, nullable=False), Column('household_data', VARCHAR(length=28), table=<by_race>), Column('total_workers_2017', INTEGER(), table=<by_race>), Column('total_workers_2018', INTEGER(), table=<by_race>), Column('median_weekly_earnings_2017', INTEGER(), table=<by_race>), Column('median_weekly_earnings_2018', INTEGER(), table=<by_race>), schema=None), 'pay_gap_by_race': Table('pay_gap_by_race', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_race>, primary_key=True, nullable=False), Column('categoryindex', VARCHAR(length=50), table=<pay_gap_by_race>, nullable=False), Column('category', VARCHAR(length=50), table=<pay_gap_by_race>), Column('total_workers', INTEGER(), table=<pay_gap_by_race>), Column('median_weekly_earnings', INTEGER(), table=<pay_gap_by_race>), Column('year', INTEGER(), table=<pay_gap_by_race>), schema=None), 'pay_gap_by_education': Table('pay_gap_by_education', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_education>, primary_key=True, nullable=False), Column('education_level', VARCHAR(length=50), table=<pay_gap_by_education>, nullable=False), Column('median_weekly_earnings_in_2018', INTEGER(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2017', INTEGER(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2016', INTEGER(), table=<pay_gap_by_education>), Column('gender', VARCHAR(length=50), table=<pay_gap_by_education>), schema=None), 'pay_gap_by_country': Table('pay_gap_by_country', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_country>, primary_key=True, nullable=False), Column('country', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('latitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('longitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('sex', VARCHAR(length=20), table=<pay_gap_by_country>, nullable=False), Column('occupation', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('currency', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('survey', TEXT(), table=<pay_gap_by_country>), Column('type_of_source', TEXT(), table=<pay_gap_by_country>), Column('year_2016_earnings', INTEGER(), table=<pay_gap_by_country>), schema=None)})

# %%
pay_gap_by_education.to_sql(name='pay_gap_by_education', con=engine, if_exists='append', index=True)
