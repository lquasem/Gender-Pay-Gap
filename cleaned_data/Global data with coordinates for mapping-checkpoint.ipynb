# %%
import pandas as pd
import numpy as np

# %%
global_data= pd.read_csv("global.csv")
coords_data= pd.read_csv("cords.csv")



# # Combine the data into a single dataset
cords_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
global_data.head(5)
# Out:
#      Country           Sex                 Currency   2006  2007   2008  \
# 0  Argentina   Total (Sex)  U.S. dollars (Currency)  336.0   NaN  521.0
# 1  Argentina    Male (Sex)  U.S. dollars (Currency)  388.0   NaN  593.0
# 2  Argentina  Female (Sex)  U.S. dollars (Currency)  271.0   NaN  429.0
# 3     Brazil   Total (Sex)  U.S. dollars (Currency)    NaN   NaN    NaN
# 4     Brazil    Male (Sex)  U.S. dollars (Currency)    NaN   NaN    NaN
#
#     2009   2010   2011   2012    2013   2014   2015   2016  2017
# 0  531.0  621.0  767.0  865.0   914.0  800.0    NaN    NaN   NaN
# 1  593.0  695.0  862.0  972.0  1027.0  898.0    NaN    NaN   NaN
# 2  452.0  525.0  643.0  728.0   769.0  675.0    NaN    NaN   NaN
# 3    NaN    NaN    NaN  724.0   711.0  711.0  552.0  590.0   NaN
# 4    NaN    NaN    NaN  813.0   796.0  800.0  618.0  654.0   NaN

# %%
# # # Read S Data File and store into Pandas Data Frames

coords_data.head(5)
# Out:
#           Country           Capital Latitude Longitude
# 0     Afghanistan             Kabul  34°28'N   69°11'E
# 1         Albania            Tirane  41°18'N   19°49'E
# 2         Algeria           Algiers  36°42'N   03°08'E
# 3  American Samoa         Pago Pago  14°16'S  170°43'W
# 4         Andorra  Andorra la Vella  42°31'N   01°32'E

# %%
# Merge two dataframes using an inner join
merge_table = pd.merge(coords_data, global_data ,on="Country")

merge_table.head()
# Out:
#      Country       Capital Latitude Longitude           Sex  \
# 0  Argentina  Buenos Aires  36°30'S   60°00'W   Total (Sex)
# 1  Argentina  Buenos Aires  36°30'S   60°00'W    Male (Sex)
# 2  Argentina  Buenos Aires  36°30'S   60°00'W  Female (Sex)
# 3     Brazil      Brasilia  15°47'S   47°55'W   Total (Sex)
# 4     Brazil      Brasilia  15°47'S   47°55'W    Male (Sex)
#
#                   Currency   2006  2007   2008   2009   2010   2011   2012  \
# 0  U.S. dollars (Currency)  336.0   NaN  521.0  531.0  621.0  767.0  865.0
# 1  U.S. dollars (Currency)  388.0   NaN  593.0  593.0  695.0  862.0  972.0
# 2  U.S. dollars (Currency)  271.0   NaN  429.0  452.0  525.0  643.0  728.0
# 3  U.S. dollars (Currency)    NaN   NaN    NaN    NaN    NaN    NaN  724.0
# 4  U.S. dollars (Currency)    NaN   NaN    NaN    NaN    NaN    NaN  813.0
#
#      2013   2014   2015   2016  2017
# 0   914.0  800.0    NaN    NaN   NaN
# 1  1027.0  898.0    NaN    NaN   NaN
# 2   769.0  675.0    NaN    NaN   NaN
# ...

# %%
merge_table. to_csv("Global_coords.csv")

# %%
df.dropna()
