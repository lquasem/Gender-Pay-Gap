# %%
#Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
path = "data/Median_weekly_earnings_by_detailed_occupation_and_sex_2018.csv"

# %%
# Use encoding to read the CSV in pandas
table =pd.read_csv(path, encoding="UTF-8")

# %%
 # Preview of the DataFrame
table.head(10)
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n39. Median weekly earnings of full-time wage and salary workers by detailed occupation and sex  \
# 0           Total, full-time wage and salary workers
# 1  Management, professional, and related occupations
# 2  Management, business, and financial operations...
# 3                             Management occupations
# 4                                   Chief executives
# 5                    General and operations managers
# 6                                        Legislators
# 7                Advertising and promotions managers
# 8                       Marketing and sales managers
# 9          Public relations and fundraising managers
#
#   Total Number of Workers in 2018 Median weekly earnings in 2018  \
# 0                         115,567                           $886
# 1                          48,808                          1,246
# 2                          19,863                          1,355
# ...

# %%
list(table.columns)
# Out:
# ['HOUSEHOLD DATA\nANNUAL AVERAGES\n39. Median weekly earnings of full-time wage and salary workers by detailed occupation and sex',
#  'Total Number of Workers in 2018',
#  'Median weekly earnings in 2018',
#  'Total Number of Men Workers in 2018',
#  'Median weekly earnings of men in 2018',
#  'Total Number of Women Workers in 2018',
#  'Median weekly earnings of women in 2018']

# %%
#Rename the column names
table = table.rename(columns ={'HOUSEHOLD DATA\nANNUAL AVERAGES\n39. Median weekly earnings of full-time wage and salary workers by detailed occupation and sex':'By occupation',
                               'Column1': 'Total Number of Workers in 2018',
                               'Column2': 'Median weekly earnings in 2018',
                               'Column3': 'Total Number of Men Workers in 2018',
                               'Column4': 'Median weekly earnings of men in 2018',
                               'Column5': 'Total Number of Women Workers in 2018',
                               'Column6': 'Median weekly earnings of women in 2018'})
table.head()
# Out:
#                                        By occupation  \
# 0           Total, full-time wage and salary workers
# 1  Management, professional, and related occupations
# 2  Management, business, and financial operations...
# 3                             Management occupations
# 4                                   Chief executives
#
#   Total Number of Workers in 2018 Median weekly earnings in 2018  \
# 0                         115,567                           $886
# 1                          48,808                          1,246
# 2                          19,863                          1,355
# 3                          13,477                          1,429
# 4                           1,098                          2,291
#
#   Total Number of Men Workers in 2018 Median weekly earnings of men in 2018  \
# 0                              64,142                                  $973
# 1                              23,685                                 1,468
# ...

# %%
# Drop all rows with missing information
table = table.dropna(how='any')
table = table.reset_index(drop=True)
table.head()
# Out:
#                                        By occupation  \
# 0           Total, full-time wage and salary workers
# 1  Management, professional, and related occupations
# 2  Management, business, and financial operations...
# 3                             Management occupations
# 4                                   Chief executives
#
#   Total Number of Workers in 2018 Median weekly earnings in 2018  \
# 0                         115,567                           $886
# 1                          48,808                          1,246
# 2                          19,863                          1,355
# 3                          13,477                          1,429
# 4                           1,098                          2,291
#
#   Total Number of Men Workers in 2018 Median weekly earnings of men in 2018  \
# 0                              64,142                                  $973
# 1                              23,685                                 1,468
# ...

# %%
# Identify incomplete rows
table.count()
# Out:
# By occupation                              565
# Total Number of Workers in 2018            565
# Median weekly earnings in 2018             565
# Total Number of Men Workers in 2018        565
# Median weekly earnings of men in 2018      565
# Total Number of Women Workers in 2018      565
# Median weekly earnings of women in 2018    565
# dtype: int64

# %%
# Name of the CSV file
path_2017 = "data/Median_weekly_earnings_by_detailed_occupation_and_sex_2017.csv"
# Use encoding to read the CSV in pandas
table_2017 =pd.read_csv(path_2017, encoding="UTF-8")
 # Preview of the DataFrame
table_2017.head(10)
# Out:
#   HOUSEHOLD DATA\nANNUAL AVERAGES\n39.  Median weekly earnings of full-time wage and salary workers by detailed occupation and sex  \
# 0                             [Numbers in thousands]
# 1                                                NaN
# 2                                         Occupation
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6           Total, full-time wage and salary workers
# 7                                                NaN
# 8  Management, professional, and related occupations
# 9  Management, business, and financial operations...
#
#           Unnamed: 1              Unnamed: 2         Unnamed: 3  \
# 0                NaN                     NaN                NaN
# 1                NaN                     NaN                NaN
# 2               2017                     NaN                NaN
# ...

# %%
list(table_2017.columns)
# Out:
# ['HOUSEHOLD DATA\nANNUAL AVERAGES\n39.  Median weekly earnings of full-time wage and salary workers by detailed occupation and sex',
#  'Total Number of Workers in 2017',
#  'Median weekly earnings in 2017',
#  'Total Number of Men Workers in 2017',
#  'Median weekly earnings of men in 2017',
#  'Total Number of Women Workers in 2017',
#  'Median weekly earnings of women in 2017']

# %%
#Rename the column names
table_2017 = table_2017.rename(columns ={'HOUSEHOLD DATA\nANNUAL AVERAGES\n39.  Median weekly earnings of full-time wage and salary workers by detailed occupation and sex': 'By occupation',
                               'Unnamed: 1': 'Total Number of Workers in 2017',
                               'Unnamed: 2': 'Median weekly earnings in 2017',
                               'Unnamed: 3': 'Total Number of Men Workers in 2017',
                               'Unnamed: 4': 'Median weekly earnings of men in 2017',
                               'Unnamed: 5': 'Total Number of Women Workers in 2017',
                               'Unnamed: 6': 'Median weekly earnings of women in 2017'})
# Drop all rows with missing information
table_2017 = table_2017.dropna(how='any')
table_2017 = table_2017.reset_index(drop=True)
table_2017.head()
# Out:
#                                        By occupation  \
# 0           Total, full-time wage and salary workers
# 1  Management, professional, and related occupations
# 2  Management, business, and financial operations...
# 3                             Management occupations
# 4                                   Chief executives
#
#   Total Number of Workers in 2017 Median weekly earnings in 2017  \
# 0                         113,272                           $860
# 1                          47,207                          1,224
# 2                          19,414                          1,327
# 3                          13,169                          1,392
# 4                           1,136                          2,296
#
#   Total Number of Men Workers in 2017 Median weekly earnings of men in 2017  \
# 0                              62,980                                  $941
# 1                              22,815                                 1,442
# ...

# %%
# Identify incomplete rows
table_2017.count()
# Out:
# By occupation                              565
# Total Number of Workers in 2017            565
# Median weekly earnings in 2017             565
# Total Number of Men Workers in 2017        565
# Median weekly earnings of men in 2017      565
# Total Number of Women Workers in 2017      565
# Median weekly earnings of women in 2017    565
# dtype: int64

# %%
# Name of the CSV file
path_2016 = "data/Median_weekly_earnings_by_detailed_occupation_and_sex_2016.csv"
# Use encoding to read the CSV in pandas
table_2016 =pd.read_csv(path_2016, encoding="UTF-8")
 # Preview of the DataFrame
table_2016.head(10)
# Out:
#   HOUSEHOLD DATA \nANNUAL AVERAGES \n39.  Median weekly earnings of full-time wage and salary workers by detailed occupation and sex  \
# 0                             [Numbers in thousands]
# 1                                                NaN
# 2                                         Occupation
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6           Total, full-time wage and salary workers
# 7                                                NaN
# 8  Management, professional, and related occupations
# 9  Management, business, and financial operations...
#
#           Unnamed: 1              Unnamed: 2         Unnamed: 3  \
# 0                NaN                     NaN                NaN
# 1                NaN                     NaN                NaN
# 2               2016                     NaN                NaN
# ...

# %%
list(table_2016.columns)
# Out:
# ['HOUSEHOLD DATA \nANNUAL AVERAGES \n39.  Median weekly earnings of full-time wage and salary workers by detailed occupation and sex',
#  'Total Number of Workers in 2016',
#  'Median weekly earnings in 2016',
#  'Total Number of Men Workers in 2016',
#  'Median weekly earnings of men in 2016',
#  'Total Number of Women Workers in 2016',
#  'Median weekly earnings of women in 2016']

# %%
#Rename the column names
table_2016 = table_2016.rename(columns ={'HOUSEHOLD DATA \nANNUAL AVERAGES \n39.  Median weekly earnings of full-time wage and salary workers by detailed occupation and sex': "By occupation",
                               'Unnamed: 1': 'Total Number of Workers in 2016',
                               'Unnamed: 2': 'Median weekly earnings in 2016',
                               'Unnamed: 3': 'Total Number of Men Workers in 2016',
                               'Unnamed: 4': 'Median weekly earnings of men in 2016',
                               'Unnamed: 5': 'Total Number of Women Workers in 2016',
                               'Unnamed: 6': 'Median weekly earnings of women in 2016'})
# Drop all rows with missing information
table_2016 = table_2016.dropna(how='any')
table_2016 = table_2016.reset_index(drop=True)
table_2016.head()
# Out:
#                                        By occupation  \
# 0           Total, full-time wage and salary workers
# 1  Management, professional, and related occupations
# 2  Management, business, and financial operations...
# 3                             Management occupations
# 4                                   Chief executives
#
#   Total Number of Workers in 2016 Median weekly earnings in 2016  \
# 0                         111,091                           $832
# 1                          45,930                          1,188
# 2                          19,023                          1,284
# 3                          12,828                          1,370
# 4                           1,150                          2,303
#
#   Total Number of Men Workers in 2016 Median weekly earnings of men in 2016  \
# 0                              61,930                                  $915
# 1                              22,256                                 1,420
# ...

# %%
# Identify incomplete rows
table_2016.count()
# Out:
# By occupation                              565
# Total Number of Workers in 2016            565
# Median weekly earnings in 2016             565
# Total Number of Men Workers in 2016        565
# Median weekly earnings of men in 2016      565
# Total Number of Women Workers in 2016      565
# Median weekly earnings of women in 2016    565
# dtype: int64

# %%
summary_table = pd.merge(table, 
                         table_2017[["By occupation","Total Number of Workers in 2017","Median weekly earnings in 2017","Total Number of Men Workers in 2017", "Median weekly earnings of men in 2017","Total Number of Women Workers in 2017", "Median weekly earnings of women in 2017"]],
                         on = 'By occupation',
                         how='left')
summary_table
# Out:
#                                          By occupation  \
# 0             Total, full-time wage and salary workers
# 1    Management, professional, and related occupations
# 2    Management, business, and financial operations...
# 3                               Management occupations
# 4                                     Chief executives
# 5                      General and operations managers
# 6                                          Legislators
# 7                  Advertising and promotions managers
# 8                         Marketing and sales managers
# 9            Public relations and fundraising managers
# 10                    Administrative services managers
# 11           Computer and information systems managers
# 12                                  Financial managers
# 13                  Compensation and benefits managers
# 14                            Human resources managers
# 15                   Training and development managers
# ...

# %%
summary_table = pd.merge(summary_table, 
                         table_2016[["By occupation","Total Number of Workers in 2016","Median weekly earnings in 2016","Total Number of Men Workers in 2016", "Median weekly earnings of men in 2016","Total Number of Women Workers in 2016", "Median weekly earnings of women in 2016"]],
                         on = 'By occupation',
                         how='left')
summary_table
# Out:
#                                          By occupation  \
# 0             Total, full-time wage and salary workers
# 1    Management, professional, and related occupations
# 2    Management, business, and financial operations...
# 3                               Management occupations
# 4                                     Chief executives
# 5                      General and operations managers
# 6                                          Legislators
# 7                  Advertising and promotions managers
# 8                         Marketing and sales managers
# 9            Public relations and fundraising managers
# 10                    Administrative services managers
# 11           Computer and information systems managers
# 12                                  Financial managers
# 13                  Compensation and benefits managers
# 14                            Human resources managers
# 15                   Training and development managers
# ...

# %%
summary_table.to_csv(r'data\by_occupation.csv', index=False)
