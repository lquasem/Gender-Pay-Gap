# %%
import pandas as pd
import numpy as np
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import MetaData
from sqlalchemy.orm import mapper
import geopandas 
import fiona
# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float

# %%
global_data= pd.read_csv("cleaned_data/by_global.csv")
coords_data= pd.read_csv("data/countries.csv")

# %%
global_data.head(5)
# Out:
#       Country           Sex                    Occupation  \
# 0     Albania    Male (Sex)  Total (Occupation (ISCO-08))
# 1     Albania  Female (Sex)  Total (Occupation (ISCO-08))
# 2     Armenia    Male (Sex)  Total (Occupation (ISCO-08))
# 3     Armenia  Female (Sex)  Total (Occupation (ISCO-08))
# 4  Azerbaijan    Male (Sex)  Total (Occupation (ISCO-08))
#
#                   Currency                               Survey  \
# 0  U.S. dollars (Currency)      General Directorate of Taxation
# 1  U.S. dollars (Currency)      General Directorate of Taxation
# 2  U.S. dollars (Currency)        Household Labour Force Survey
# 3  U.S. dollars (Currency)        Household Labour Force Survey
# 4  U.S. dollars (Currency)  Labour-related establishment survey
#
#          Type_of_Source  Year_2016
# 0     Insurance records        403
# 1     Insurance records        357
# 2   Labour force survey        249
# 3   Labour force survey        166
# 4  Establishment survey        395

# %%
# # # Read S Data File and store into Pandas Data Frames

coords_data.head(5)
# Out:
#     latitude  longitude               Country
# 0  42.546245   1.601554               Andorra
# 1  23.424076  53.847818  United Arab Emirates
# 2  33.939110  67.709953           Afghanistan
# 3  17.060816 -61.796428   Antigua and Barbuda
# 4  18.220554 -63.068615              Anguilla

# %%
# Merge two dataframes using an inner join
merge_table = pd.merge(coords_data, global_data ,on="Country")
merge_table.index.name = 'id'

merge_table.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-738e569d9e4c> in <module>
#       1 # Merge two dataframes using an inner join
# ----> 2 merge_table = pd.merge(coords_data, global_data ,on="Country")
#       3 merge_table.index.name = 'id'
#       4
#       5 merge_table.head(50)
#
# NameError: name 'pd' is not defined

# %%
merge_table.to_csv("Global_coords.csv")

# %%
# merge_table = merge_table.drop(['Capital'], axis=1)


merge_table = merge_table.rename(columns={"id": "id", 
                            "Country": "country",
                           "Latitude": "latitude",
                           "Longitude": "longitude",
                           "Sex": "sex",
                           "Occupation": "occupation",
                           "Currency": "currency",
                           "Survey": "survey",
                           "Type_of_Source": "type_of_source",
                           "Year_2016": "year_2016_earnings"})


merge_table.head()
# Out:
#      latitude  longitude     country           sex  \
# id
# 0   41.153332  20.168331     Albania    Male (Sex)
# 1   41.153332  20.168331     Albania  Female (Sex)
# 2   40.069099  45.038189     Armenia    Male (Sex)
# 3   40.069099  45.038189     Armenia  Female (Sex)
# 4   40.143105  47.576927  Azerbaijan    Male (Sex)
#
#                       occupation                 currency  \
# id
# 0   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 1   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 2   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 3   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 4   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
#
#                                  survey        type_of_source  \
# id
# 0       General Directorate of Taxation     Insurance records
# 1       General Directorate of Taxation     Insurance records
# 2         Household Labour Force Survey   Labour force survey
# 3         Household Labour Force Survey   Labour force survey
# 4   Labour-related establishment survey  Establishment survey
#
#     year_2016_earnings
# id
# 0                  403
# 1                  357
# 2                  249
# 3                  166
# 4                  395

# %%
print (merge_table.dtypes)
# Out:
# latitude              float64
# longitude             float64
# country                object
# sex                    object
# occupation             object
# currency               object
# survey                 object
# type_of_source         object
# year_2016_earnings      int64
# dtype: object

# %%
merge_table['latitude'] = merge_table['latitude'].astype(int)
merge_table['longitude'] = merge_table['longitude'].astype(int)

# %%
# gdf = geopandas.GeoDataFrame(
#     merge_table, geometry=geopandas[Point(x, y) for x, y in zip(merge_table.Longitude,merge_table.Latitude)])

from geopandas import GeoDataFrame
from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(merge_table.longitude,merge_table.latitude)]
merge_table = merge_table.drop(['longitude', 'latitude'], axis=1)
crs = {'init': 'epsg:4326'}
gdf = GeoDataFrame(merge_table, crs=crs, geometry=geometry)


gdf
# Out:
#                    country           sex                    occupation  \
# id
# 0                  Albania    Male (Sex)  Total (Occupation (ISCO-08))
# 1                  Albania  Female (Sex)  Total (Occupation (ISCO-08))
# 2                  Armenia    Male (Sex)  Total (Occupation (ISCO-08))
# 3                  Armenia  Female (Sex)  Total (Occupation (ISCO-08))
# 4               Azerbaijan    Male (Sex)  Total (Occupation (ISCO-08))
# 5               Azerbaijan  Female (Sex)  Total (Occupation (ISCO-08))
# 6   Bosnia and Herzegovina    Male (Sex)  Total (Occupation (ISCO-08))
# 7   Bosnia and Herzegovina  Female (Sex)  Total (Occupation (ISCO-08))
# 8               Bangladesh    Male (Sex)  Total (Occupation (ISCO-08))
# 9               Bangladesh  Female (Sex)  Total (Occupation (ISCO-08))
# 10                 Belgium    Male (Sex)  Total (Occupation (ISCO-08))
# 11                 Belgium  Female (Sex)  Total (Occupation (ISCO-08))
# 12                 Bolivia    Male (Sex)  Total (Occupation (ISCO-08))
# 13                 Bolivia  Female (Sex)  Total (Occupation (ISCO-08))
# 14                  Brazil    Male (Sex)  Total (Occupation (ISCO-08))
# 15                  Brazil  Female (Sex)  Total (Occupation (ISCO-08))
# 16                  Belize    Male (Sex)  Total (Occupation (ISCO-08))
# 17                  Belize  Female (Sex)  Total (Occupation (ISCO-08))
# 18              Costa Rica    Male (Sex)  Total (Occupation (ISCO-08))
# 19              Costa Rica  Female (Sex)  Total (Occupation (ISCO-08))
# 20              Costa Rica    Male (Sex)  Total (Occupation (ISCO-08))
# 21              Costa Rica  Female (Sex)  Total (Occupation (ISCO-08))
# 22          Czech Republic    Male (Sex)  Total (Occupation (ISCO-08))
# 23          Czech Republic  Female (Sex)  Total (Occupation (ISCO-08))
# 24      Dominican Republic    Male (Sex)  Total (Occupation (ISCO-08))
# 25      Dominican Republic  Female (Sex)  Total (Occupation (ISCO-08))
# 26                 Ecuador    Male (Sex)  Total (Occupation (ISCO-08))
# 27                 Ecuador  Female (Sex)  Total (Occupation (ISCO-08))
# 28                   Egypt    Male (Sex)  Total (Occupation (ISCO-08))
# 29                   Egypt  Female (Sex)  Total (Occupation (ISCO-08))
# ..                     ...           ...                           ...
# 60                Malaysia    Male (Sex)  Total (Occupation (ISCO-08))
# 61                Malaysia  Female (Sex)  Total (Occupation (ISCO-08))
# 62                  Panama    Male (Sex)  Total (Occupation (ISCO-08))
# 63                  Panama  Female (Sex)  Total (Occupation (ISCO-08))
# 64                Pakistan    Male (Sex)  Total (Occupation (ISCO-08))
# 65                Pakistan  Female (Sex)  Total (Occupation (ISCO-08))
# 66                  Poland    Male (Sex)  Total (Occupation (ISCO-08))
# 67                  Poland  Female (Sex)  Total (Occupation (ISCO-08))
# 68                Portugal    Male (Sex)  Total (Occupation (ISCO-08))
# 69                Portugal  Female (Sex)  Total (Occupation (ISCO-08))
# 70                Paraguay    Male (Sex)  Total (Occupation (ISCO-08))
# 71                Paraguay  Female (Sex)  Total (Occupation (ISCO-08))
# 72                 Romania    Male (Sex)  Total (Occupation (ISCO-08))
# 73                 Romania  Female (Sex)  Total (Occupation (ISCO-08))
# 74                  Serbia    Male (Sex)  Total (Occupation (ISCO-08))
# 75                  Serbia  Female (Sex)  Total (Occupation (ISCO-08))
# 76                Slovenia    Male (Sex)  Total (Occupation (ISCO-08))
# 77                Slovenia  Female (Sex)  Total (Occupation (ISCO-08))
# 78                Slovakia    Male (Sex)  Total (Occupation (ISCO-08))
# 79                Slovakia  Female (Sex)  Total (Occupation (ISCO-08))
# 80             El Salvador    Male (Sex)  Total (Occupation (ISCO-08))
# 81             El Salvador  Female (Sex)  Total (Occupation (ISCO-08))
# 82                Thailand    Male (Sex)  Total (Occupation (ISCO-08))
# 83                Thailand  Female (Sex)  Total (Occupation (ISCO-08))
# 84             Timor-Leste    Male (Sex)  Total (Occupation (ISCO-08))
# 85             Timor-Leste  Female (Sex)  Total (Occupation (ISCO-08))
# 86                 Ukraine    Male (Sex)  Total (Occupation (ISCO-08))
# 87                 Ukraine  Female (Sex)  Total (Occupation (ISCO-08))
# 88                 Uruguay    Male (Sex)  Total (Occupation (ISCO-08))
# 89                 Uruguay  Female (Sex)  Total (Occupation (ISCO-08))
#
#                    currency  \
# id
# 0   U.S. dollars (Currency)
# 1   U.S. dollars (Currency)
# 2   U.S. dollars (Currency)
# 3   U.S. dollars (Currency)
# 4   U.S. dollars (Currency)
# 5   U.S. dollars (Currency)
# 6   U.S. dollars (Currency)
# 7   U.S. dollars (Currency)
# 8   U.S. dollars (Currency)
# 9   U.S. dollars (Currency)
# 10  U.S. dollars (Currency)
# 11  U.S. dollars (Currency)
# 12  U.S. dollars (Currency)
# 13  U.S. dollars (Currency)
# 14  U.S. dollars (Currency)
# 15  U.S. dollars (Currency)
# 16  U.S. dollars (Currency)
# 17  U.S. dollars (Currency)
# 18  U.S. dollars (Currency)
# 19  U.S. dollars (Currency)
# 20  U.S. dollars (Currency)
# 21  U.S. dollars (Currency)
# 22  U.S. dollars (Currency)
# 23  U.S. dollars (Currency)
# 24  U.S. dollars (Currency)
# 25  U.S. dollars (Currency)
# 26  U.S. dollars (Currency)
# 27  U.S. dollars (Currency)
# 28  U.S. dollars (Currency)
# 29  U.S. dollars (Currency)
# ..                      ...
# 60  U.S. dollars (Currency)
# 61  U.S. dollars (Currency)
# 62  U.S. dollars (Currency)
# 63  U.S. dollars (Currency)
# 64  U.S. dollars (Currency)
# 65  U.S. dollars (Currency)
# 66  U.S. dollars (Currency)
# 67  U.S. dollars (Currency)
# 68  U.S. dollars (Currency)
# 69  U.S. dollars (Currency)
# 70  U.S. dollars (Currency)
# 71  U.S. dollars (Currency)
# 72  U.S. dollars (Currency)
# 73  U.S. dollars (Currency)
# 74  U.S. dollars (Currency)
# 75  U.S. dollars (Currency)
# 76  U.S. dollars (Currency)
# 77  U.S. dollars (Currency)
# 78  U.S. dollars (Currency)
# 79  U.S. dollars (Currency)
# 80  U.S. dollars (Currency)
# 81  U.S. dollars (Currency)
# 82  U.S. dollars (Currency)
# 83  U.S. dollars (Currency)
# 84  U.S. dollars (Currency)
# 85  U.S. dollars (Currency)
# 86  U.S. dollars (Currency)
# 87  U.S. dollars (Currency)
# 88  U.S. dollars (Currency)
# 89  U.S. dollars (Currency)
#
#                                                survey  \
# id
# 0                     General Directorate of Taxation
# 1                     General Directorate of Taxation
# 2                       Household Labour Force Survey
# 3                       Household Labour Force Survey
# 4                 Labour-related establishment survey
# 5                 Labour-related establishment survey
# 6                                 Labour Force Survey
# 7                                 Labour Force Survey
# 8                                 Labour Force Survey
# 9                                 Labour Force Survey
# 10                       Structure of Earnings Survey
# 11                       Structure of Earnings Survey
# 12                       Continuous Employment Survey
# 13                       Continuous Employment Survey
# 14        Continuous National Household Sample Survey
# 15        Continuous National Household Sample Survey
# 16                                Labour force survey
# 17                                Labour force survey
# 18                          National Household Survey
# 19                          National Household Survey
# 20                    National Business Survey (ENAE)
# 21                    National Business Survey (ENAE)
# 22                    Survey on Structure of Earnings
# 23                    Survey on Structure of Earnings
# 24            Continuous National Labour Force Survey
# 25            Continuous National Labour Force Survey
# 26  National Survey on Employment, Unemployment an...
# 27  National Survey on Employment, Unemployment an...
# 28                         Labour force sample survey
# 29                         Labour force sample survey
# ..                                                ...
# 60                          Salaries and Wages Survey
# 61                          Salaries and Wages Survey
# 62                               Labour Market Survey
# 63                               Labour Market Survey
# 64                                Labour Force Survey
# 65                                Labour Force Survey
# 66                       Structure of Earnings Survey
# 67                       Structure of Earnings Survey
# 68                                  Employment Survey
# 69                                  Employment Survey
# 70                         Continous Household Survey
# 71                         Continous Household Survey
# 72                                 Labour cost survey
# 73                                 Labour cost survey
# 74                                Labour force survey
# 75                                Labour force survey
# 76                      Structure of earnings records
# 77                      Structure of earnings records
# 78                Annual Structure of Earnings Survey
# 79                Annual Structure of Earnings Survey
# 80                     Multi-purpose household survey
# 81                     Multi-purpose household survey
# 82                                Labour force survey
# 83                                Labour force survey
# 84                                Labour Force Survey
# 85                                Labour Force Survey
# 86  Survey on wages of employees by gender, age, e...
# 87  Survey on wages of employees by gender, age, e...
# 88                         Continous Household Survey
# 89                         Continous Household Survey
#
#                                       type_of_source  year_2016_earnings  \
# id
# 0                                  Insurance records                 403
# 1                                  Insurance records                 357
# 2                                Labour force survey                 249
# 3                                Labour force survey                 166
# 4                               Establishment survey                 395
# 5                               Establishment survey                 199
# 6                                Labour force survey                 441
# 7                                Labour force survey                 386
# 8                                Labour force survey                 167
# 9                                Labour force survey                 154
# 10                              Establishment survey                3634
# 11                              Establishment survey                2901
# 12                               Labour force survey                 483
# 13                               Labour force survey                 364
# 14                            Other household survey                 654
# 15                            Other household survey                 516
# 16                               Labour force survey                 586
# 17                               Labour force survey                 566
# 18                            Other household survey                 967
# 19                            Other household survey                 868
# 20                              Establishment survey                 939
# 21                              Establishment survey                 929
# 22                              Establishment survey                1312
# 23                              Establishment survey                1036
# 24                               Labour force survey                 321
# 25                               Labour force survey                 216
# 26                               Labour force survey                 499
# 27                               Labour force survey                 496
# 28                               Labour force survey                 225
# 29                               Labour force survey                 182
# ..                                               ...                 ...
# 60                              Establishment survey                 603
# 61                              Establishment survey                 578
# 62                               Labour force survey                 809
# 63                               Labour force survey                 795
# 64                               Labour force survey                 151
# 65                               Labour force survey                  93
# 66                              Establishment survey                1193
# 67                              Establishment survey                1007
# 68                               Labour force survey                1012
# 69                               Labour force survey                 852
# 70                            Other household survey                 401
# 71                            Other household survey                 326
# 72                              Establishment survey                 714
# 73                              Establishment survey                 667
# 74                               Labour force survey                 331
# 75                               Labour force survey                 301
# 76  Other administrative records and related sources                1916
# 77  Other administrative records and related sources                1803
# 78                              Establishment survey                1291
# 79                              Establishment survey                1007
# 80                            Other household survey                 303
# 81                            Other household survey                 286
# 82                               Labour force survey                 421
# 83                               Labour force survey                 419
# 84                               Labour force survey                 308
# 85                               Labour force survey                 367
# 86                              Establishment survey                 215
# 87                              Establishment survey                 166
# 88                               Labour force survey                 955
# 89                               Labour force survey                 754
#
#            geometry
# id
# 0     POINT (20 41)
# 1     POINT (20 41)
# 2     POINT (45 40)
# 3     POINT (45 40)
# 4     POINT (47 40)
# 5     POINT (47 40)
# 6     POINT (17 43)
# 7     POINT (17 43)
# 8     POINT (90 23)
# 9     POINT (90 23)
# 10     POINT (4 50)
# 11     POINT (4 50)
# 12  POINT (-63 -16)
# 13  POINT (-63 -16)
# 14  POINT (-51 -14)
# 15  POINT (-51 -14)
# 16   POINT (-88 17)
# 17   POINT (-88 17)
# 18    POINT (-83 9)
# 19    POINT (-83 9)
# 20    POINT (-83 9)
# 21    POINT (-83 9)
# 22    POINT (15 49)
# 23    POINT (15 49)
# 24   POINT (-70 18)
# 25   POINT (-70 18)
# 26   POINT (-78 -1)
# 27   POINT (-78 -1)
# 28    POINT (30 26)
# 29    POINT (30 26)
# ..              ...
# 60    POINT (101 4)
# 61    POINT (101 4)
# 62    POINT (-80 8)
# 63    POINT (-80 8)
# 64    POINT (69 30)
# 65    POINT (69 30)
# 66    POINT (19 51)
# 67    POINT (19 51)
# 68    POINT (-8 39)
# 69    POINT (-8 39)
# 70  POINT (-58 -23)
# 71  POINT (-58 -23)
# 72    POINT (24 45)
# 73    POINT (24 45)
# 74    POINT (21 44)
# 75    POINT (21 44)
# 76    POINT (14 46)
# 77    POINT (14 46)
# 78    POINT (19 48)
# 79    POINT (19 48)
# 80   POINT (-88 13)
# 81   POINT (-88 13)
# 82   POINT (100 15)
# 83   POINT (100 15)
# 84   POINT (125 -8)
# 85   POINT (125 -8)
# 86    POINT (31 48)
# 87    POINT (31 48)
# 88  POINT (-55 -32)
# 89  POINT (-55 -32)
#
# [90 rows x 8 columns]

# %%
gdf.to_file("countries.geojson", driver='GeoJSON')

# %%
merge_table.to_csv("Global_coords.csv")
# merge_table.head(10)

# %%
engine = create_engine('postgresql://postgres:'+ password + '@localhost:5432/gender_pay_gap')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a8331aea459a> in <module>
# ----> 1 engine = create_engine('postgresql://postgres:'+ password + '@localhost:5432/gender_pay_gap')
#
# NameError: name 'password' is not defined

# %%
#engine.table_names()
metadata = MetaData()
metadata.reflect(bind=engine)
print(metadata.tables)

# %%
merge_table.to_sql(name='pay_gap_by_country', con=engine, if_exists='append', index=True)
