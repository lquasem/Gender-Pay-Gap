# %%
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import MetaData
from sqlalchemy.orm import mapper
from config import password

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

import pandas as pd

# %%
path = "gender_race.csv"
pay_gap_by_gender_table = pd.read_csv(path, encoding="UTF-8")
pay_gap_by_gender_table.index.name = 'id'
pay_gap_by_gender_table.head()
# Out:
#    categoryindex category  total_workers  median_weekly_earnings  year
# id
# 0          Total    Total         113272                     860  2017
# 1      Total_Men      Men          62980                     941  2017
# 2    Total_Women    Women          50291                     770  2017
# 3    White_Total    White          87730                     890  2017
# 4      White_Men      Men          50003                     971  2017

# %%
engine = create_engine('postgresql://postgres:'+ password + '@localhost:5432/gender_pay_gap')

# %%
#engine.table_names()
metadata = MetaData()
metadata.reflect(bind=engine)
print(metadata.tables)
# Out:
# immutabledict({'pay_gap_by_country': Table('pay_gap_by_country', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_country>, primary_key=True, nullable=False), Column('country', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('latitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('longitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('sex', VARCHAR(length=20), table=<pay_gap_by_country>, nullable=False), Column('occupation', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('currency', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('survey', TEXT(), table=<pay_gap_by_country>), Column('type_of_source', TEXT(), table=<pay_gap_by_country>), Column('year_2016_earnings', INTEGER(), table=<pay_gap_by_country>), schema=None), 'pay_by_race': Table('pay_by_race', MetaData(bind=None), Column('id', BIGINT(), table=<pay_by_race>), Column('categoryindex', TEXT(), table=<pay_by_race>), Column('category', TEXT(), table=<pay_by_race>), Column('total_workers', BIGINT(), table=<pay_by_race>), Column('median_weekly_earnings', BIGINT(), table=<pay_by_race>), Column('year', BIGINT(), table=<pay_by_race>), schema=None), 'pay_by_country': Table('pay_by_country', MetaData(bind=None), Column('id', BIGINT(), table=<pay_by_country>), Column('latitude', DOUBLE_PRECISION(precision=53), table=<pay_by_country>), Column('longitude', DOUBLE_PRECISION(precision=53), table=<pay_by_country>), Column('country', TEXT(), table=<pay_by_country>), Column('sex', TEXT(), table=<pay_by_country>), Column('occupation', TEXT(), table=<pay_by_country>), Column('currency', TEXT(), table=<pay_by_country>), Column('survey', TEXT(), table=<pay_by_country>), Column('type_of_source', TEXT(), table=<pay_by_country>), Column('year_2016_earnings', BIGINT(), table=<pay_by_country>), schema=None), 'pay_gap_by_education': Table('pay_gap_by_education', MetaData(bind=None), Column('id', BIGINT(), table=<pay_gap_by_education>), Column('education_level', TEXT(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2018', BIGINT(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2017', BIGINT(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2016', BIGINT(), table=<pay_gap_by_education>), Column('gender', TEXT(), table=<pay_gap_by_education>), schema=None), 'pay_gap_by_race': Table('pay_gap_by_race', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_race>, primary_key=True, nullable=False), Column('categoryindex', VARCHAR(length=50), table=<pay_gap_by_race>, nullable=False), Column('category', VARCHAR(length=50), table=<pay_gap_by_race>), Column('total_workers', INTEGER(), table=<pay_gap_by_race>), Column('median_weekly_earnings', INTEGER(), table=<pay_gap_by_race>), Column('year', INTEGER(), table=<pay_gap_by_race>), schema=None)})

# %%
pay_gap_by_gender_table.to_sql(name='pay_gap_by_race', con=engine, if_exists='append', index=True)

# %% [markdown]
# # Loading data for gender_pay_gap_byCountry

# %%
global_data= pd.read_csv("by_global.csv")
coords_data= pd.read_csv("../data/countries.csv")

# %%
global_data.head(5)
# Out:
#       Country           Sex                    Occupation  \
# 0     Albania    Male (Sex)  Total (Occupation (ISCO-08))
# 1     Albania  Female (Sex)  Total (Occupation (ISCO-08))
# 2     Armenia    Male (Sex)  Total (Occupation (ISCO-08))
# 3     Armenia  Female (Sex)  Total (Occupation (ISCO-08))
# 4  Azerbaijan    Male (Sex)  Total (Occupation (ISCO-08))
#
#                   Currency                               Survey  \
# 0  U.S. dollars (Currency)      General Directorate of Taxation
# 1  U.S. dollars (Currency)      General Directorate of Taxation
# 2  U.S. dollars (Currency)        Household Labour Force Survey
# 3  U.S. dollars (Currency)        Household Labour Force Survey
# 4  U.S. dollars (Currency)  Labour-related establishment survey
#
#          Type_of_Source  Year_2016
# 0     Insurance records        403
# 1     Insurance records        357
# 2   Labour force survey        249
# 3   Labour force survey        166
# 4  Establishment survey        395

# %%
coords_data.head(5)
# Out:
#     latitude  longitude               Country
# 0  42.546245   1.601554               Andorra
# 1  23.424076  53.847818  United Arab Emirates
# 2  33.939110  67.709953           Afghanistan
# 3  17.060816 -61.796428   Antigua and Barbuda
# 4  18.220554 -63.068615              Anguilla

# %%
# Merge two dataframes using an inner join
global_coords_merged_table = pd.merge(coords_data, global_data ,on="Country")
global_coords_merged_table.index.name = 'id'

global_coords_merged_table.head(100)
# Out:
#      latitude   longitude                 Country           Sex  \
# id
# 0   41.153332   20.168331                 Albania    Male (Sex)
# 1   41.153332   20.168331                 Albania  Female (Sex)
# 2   40.069099   45.038189                 Armenia    Male (Sex)
# 3   40.069099   45.038189                 Armenia  Female (Sex)
# 4   40.143105   47.576927              Azerbaijan    Male (Sex)
# 5   40.143105   47.576927              Azerbaijan  Female (Sex)
# 6   43.915886   17.679076  Bosnia and Herzegovina    Male (Sex)
# 7   43.915886   17.679076  Bosnia and Herzegovina  Female (Sex)
# 8   23.684994   90.356331              Bangladesh    Male (Sex)
# 9   23.684994   90.356331              Bangladesh  Female (Sex)
# 10  50.503887    4.469936                 Belgium    Male (Sex)
# 11  50.503887    4.469936                 Belgium  Female (Sex)
# 12 -16.290154  -63.588653                 Bolivia    Male (Sex)
# 13 -16.290154  -63.588653                 Bolivia  Female (Sex)
# 14 -14.235004  -51.925280                  Brazil    Male (Sex)
# 15 -14.235004  -51.925280                  Brazil  Female (Sex)
# 16  17.189877  -88.497650                  Belize    Male (Sex)
# 17  17.189877  -88.497650                  Belize  Female (Sex)
# 18   9.748917  -83.753428              Costa Rica    Male (Sex)
# 19   9.748917  -83.753428              Costa Rica  Female (Sex)
# 20   9.748917  -83.753428              Costa Rica    Male (Sex)
# 21   9.748917  -83.753428              Costa Rica  Female (Sex)
# 22  49.817492   15.472962          Czech Republic    Male (Sex)
# 23  49.817492   15.472962          Czech Republic  Female (Sex)
# 24  18.735693  -70.162651      Dominican Republic    Male (Sex)
# 25  18.735693  -70.162651      Dominican Republic  Female (Sex)
# 26  -1.831239  -78.183406                 Ecuador    Male (Sex)
# 27  -1.831239  -78.183406                 Ecuador  Female (Sex)
# 28  26.820553   30.802498                   Egypt    Male (Sex)
# 29  26.820553   30.802498                   Egypt  Female (Sex)
# ..        ...         ...                     ...           ...
# 60   4.210484  101.975766                Malaysia    Male (Sex)
# 61   4.210484  101.975766                Malaysia  Female (Sex)
# 62   8.537981  -80.782127                  Panama    Male (Sex)
# 63   8.537981  -80.782127                  Panama  Female (Sex)
# 64  30.375321   69.345116                Pakistan    Male (Sex)
# 65  30.375321   69.345116                Pakistan  Female (Sex)
# 66  51.919438   19.145136                  Poland    Male (Sex)
# 67  51.919438   19.145136                  Poland  Female (Sex)
# 68  39.399872   -8.224454                Portugal    Male (Sex)
# 69  39.399872   -8.224454                Portugal  Female (Sex)
# 70 -23.442503  -58.443832                Paraguay    Male (Sex)
# 71 -23.442503  -58.443832                Paraguay  Female (Sex)
# 72  45.943161   24.966760                 Romania    Male (Sex)
# 73  45.943161   24.966760                 Romania  Female (Sex)
# 74  44.016521   21.005859                  Serbia    Male (Sex)
# 75  44.016521   21.005859                  Serbia  Female (Sex)
# 76  46.151241   14.995463                Slovenia    Male (Sex)
# 77  46.151241   14.995463                Slovenia  Female (Sex)
# 78  48.669026   19.699024                Slovakia    Male (Sex)
# 79  48.669026   19.699024                Slovakia  Female (Sex)
# 80  13.794185  -88.896530             El Salvador    Male (Sex)
# 81  13.794185  -88.896530             El Salvador  Female (Sex)
# 82  15.870032  100.992541                Thailand    Male (Sex)
# 83  15.870032  100.992541                Thailand  Female (Sex)
# 84  -8.874217  125.727539             Timor-Leste    Male (Sex)
# 85  -8.874217  125.727539             Timor-Leste  Female (Sex)
# 86  48.379433   31.165580                 Ukraine    Male (Sex)
# 87  48.379433   31.165580                 Ukraine  Female (Sex)
# 88 -32.522779  -55.765835                 Uruguay    Male (Sex)
# 89 -32.522779  -55.765835                 Uruguay  Female (Sex)
#
#                       Occupation                 Currency  \
# id
# 0   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 1   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 2   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 3   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 4   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 5   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 6   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 7   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 8   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 9   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 10  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 11  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 12  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 13  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 14  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 15  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 16  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 17  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 18  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 19  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 20  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 21  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 22  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 23  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 24  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 25  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 26  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 27  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 28  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 29  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# ..                           ...                      ...
# 60  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 61  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 62  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 63  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 64  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 65  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 66  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 67  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 68  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 69  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 70  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 71  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 72  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 73  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 74  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 75  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 76  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 77  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 78  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 79  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 80  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 81  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 82  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 83  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 84  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 85  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 86  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 87  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 88  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 89  Total (Occupation (ISCO-08))  U.S. dollars (Currency)
#
#                                                Survey  \
# id
# 0                     General Directorate of Taxation
# 1                     General Directorate of Taxation
# 2                       Household Labour Force Survey
# 3                       Household Labour Force Survey
# 4                 Labour-related establishment survey
# 5                 Labour-related establishment survey
# 6                                 Labour Force Survey
# 7                                 Labour Force Survey
# 8                                 Labour Force Survey
# 9                                 Labour Force Survey
# 10                       Structure of Earnings Survey
# 11                       Structure of Earnings Survey
# 12                       Continuous Employment Survey
# 13                       Continuous Employment Survey
# 14        Continuous National Household Sample Survey
# 15        Continuous National Household Sample Survey
# 16                                Labour force survey
# 17                                Labour force survey
# 18                          National Household Survey
# 19                          National Household Survey
# 20                    National Business Survey (ENAE)
# 21                    National Business Survey (ENAE)
# 22                    Survey on Structure of Earnings
# 23                    Survey on Structure of Earnings
# 24            Continuous National Labour Force Survey
# 25            Continuous National Labour Force Survey
# 26  National Survey on Employment, Unemployment an...
# 27  National Survey on Employment, Unemployment an...
# 28                         Labour force sample survey
# 29                         Labour force sample survey
# ..                                                ...
# 60                          Salaries and Wages Survey
# 61                          Salaries and Wages Survey
# 62                               Labour Market Survey
# 63                               Labour Market Survey
# 64                                Labour Force Survey
# 65                                Labour Force Survey
# 66                       Structure of Earnings Survey
# 67                       Structure of Earnings Survey
# 68                                  Employment Survey
# 69                                  Employment Survey
# 70                         Continous Household Survey
# 71                         Continous Household Survey
# 72                                 Labour cost survey
# 73                                 Labour cost survey
# 74                                Labour force survey
# 75                                Labour force survey
# 76                      Structure of earnings records
# 77                      Structure of earnings records
# 78                Annual Structure of Earnings Survey
# 79                Annual Structure of Earnings Survey
# 80                     Multi-purpose household survey
# 81                     Multi-purpose household survey
# 82                                Labour force survey
# 83                                Labour force survey
# 84                                Labour Force Survey
# 85                                Labour Force Survey
# 86  Survey on wages of employees by gender, age, e...
# 87  Survey on wages of employees by gender, age, e...
# 88                         Continous Household Survey
# 89                         Continous Household Survey
#
#                                       Type_of_Source  Year_2016
# id
# 0                                  Insurance records        403
# 1                                  Insurance records        357
# 2                                Labour force survey        249
# 3                                Labour force survey        166
# 4                               Establishment survey        395
# 5                               Establishment survey        199
# 6                                Labour force survey        441
# 7                                Labour force survey        386
# 8                                Labour force survey        167
# 9                                Labour force survey        154
# 10                              Establishment survey       3634
# 11                              Establishment survey       2901
# 12                               Labour force survey        483
# 13                               Labour force survey        364
# 14                            Other household survey        654
# 15                            Other household survey        516
# 16                               Labour force survey        586
# 17                               Labour force survey        566
# 18                            Other household survey        967
# 19                            Other household survey        868
# 20                              Establishment survey        939
# 21                              Establishment survey        929
# 22                              Establishment survey       1312
# 23                              Establishment survey       1036
# 24                               Labour force survey        321
# 25                               Labour force survey        216
# 26                               Labour force survey        499
# 27                               Labour force survey        496
# 28                               Labour force survey        225
# 29                               Labour force survey        182
# ..                                               ...        ...
# 60                              Establishment survey        603
# 61                              Establishment survey        578
# 62                               Labour force survey        809
# 63                               Labour force survey        795
# 64                               Labour force survey        151
# 65                               Labour force survey         93
# 66                              Establishment survey       1193
# 67                              Establishment survey       1007
# 68                               Labour force survey       1012
# 69                               Labour force survey        852
# 70                            Other household survey        401
# 71                            Other household survey        326
# 72                              Establishment survey        714
# 73                              Establishment survey        667
# 74                               Labour force survey        331
# 75                               Labour force survey        301
# 76  Other administrative records and related sources       1916
# 77  Other administrative records and related sources       1803
# 78                              Establishment survey       1291
# 79                              Establishment survey       1007
# 80                            Other household survey        303
# 81                            Other household survey        286
# 82                               Labour force survey        421
# 83                               Labour force survey        419
# 84                               Labour force survey        308
# 85                               Labour force survey        367
# 86                              Establishment survey        215
# 87                              Establishment survey        166
# 88                               Labour force survey        955
# 89                               Labour force survey        754
#
# [90 rows x 9 columns]

# %%
#global_coords_merged_table = global_coords_merged_table.drop(['Capital'], axis=1)


global_coords_merged_table = global_coords_merged_table.rename(columns={"id": "id", 
                            "Country": "country",
                           "Latitude": "latitude",
                           "Longitude": "longitude",
                           "Sex": "sex",
                           "Occupation": "occupation",
                           "Currency": "currency",
                           "Survey": "survey",
                           "Type_of_Source": "type_of_source",
                           "Year_2016": "year_2016_earnings"})

# %%
global_coords_merged_table.to_csv("Global_coords.csv")
global_coords_merged_table.head(10)
# Out:
#      latitude  longitude                 country           sex  \
# id
# 0   41.153332  20.168331                 Albania    Male (Sex)
# 1   41.153332  20.168331                 Albania  Female (Sex)
# 2   40.069099  45.038189                 Armenia    Male (Sex)
# 3   40.069099  45.038189                 Armenia  Female (Sex)
# 4   40.143105  47.576927              Azerbaijan    Male (Sex)
# 5   40.143105  47.576927              Azerbaijan  Female (Sex)
# 6   43.915886  17.679076  Bosnia and Herzegovina    Male (Sex)
# 7   43.915886  17.679076  Bosnia and Herzegovina  Female (Sex)
# 8   23.684994  90.356331              Bangladesh    Male (Sex)
# 9   23.684994  90.356331              Bangladesh  Female (Sex)
#
#                       occupation                 currency  \
# id
# 0   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 1   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 2   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 3   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 4   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 5   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 6   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 7   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 8   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
# 9   Total (Occupation (ISCO-08))  U.S. dollars (Currency)
#
#                                  survey        type_of_source  \
# id
# 0       General Directorate of Taxation     Insurance records
# 1       General Directorate of Taxation     Insurance records
# 2         Household Labour Force Survey   Labour force survey
# 3         Household Labour Force Survey   Labour force survey
# 4   Labour-related establishment survey  Establishment survey
# 5   Labour-related establishment survey  Establishment survey
# 6                   Labour Force Survey   Labour force survey
# 7                   Labour Force Survey   Labour force survey
# 8                   Labour Force Survey   Labour force survey
# 9                   Labour Force Survey   Labour force survey
#
#     year_2016_earnings
# id
# 0                  403
# 1                  357
# 2                  249
# 3                  166
# 4                  395
# 5                  199
# 6                  441
# 7                  386
# 8                  167
# 9                  154

# %%
global_coords_merged_table.to_sql(name='pay_by_country', con=engine, if_exists='append', index=True)

# %% [markdown]
# # Loading data for byEducation

# %%
path_by_education = "by_education_2016-2018.csv"
pay_gap_by_education = pd.read_csv(path_by_education, encoding="UTF-8")
pay_gap_by_education.index.name = 'id'
pay_gap_by_education.head()
# Out:
#                             By education  Median weekly earnings in 2018  \
# id
# 0                 Men, 25 years and over                            1026
# 1        Less than a high school diploma                             607
# 2   High school graduates, no college(3)                             819
# 3       Some college or associate degree                             951
# 4                Some college, no degree                             918
#
#     Median weekly earnings in 2017  Median weekly earnings in 2016 Gender
# id
# 0                              996                             969   Male
# 1                              584                             551   Male
# 2                              797                             769   Male
# 3                              917                             896   Male
# 4                              886                             861   Male

# %%
pay_gap_by_education = pay_gap_by_education.rename(columns ={'By education': 'education_level',
                               'Median weekly earnings in 2018': 'median_weekly_earnings_in_2018',
                               'Median weekly earnings in 2017': 'median_weekly_earnings_in_2017',
                               'Median weekly earnings in 2016': 'median_weekly_earnings_in_2016',
                                                            'Gender':'gender'})
pay_gap_by_education.head()
# Out:
#                          education_level  median_weekly_earnings_in_2018  \
# id
# 0                 Men, 25 years and over                            1026
# 1        Less than a high school diploma                             607
# 2   High school graduates, no college(3)                             819
# 3       Some college or associate degree                             951
# 4                Some college, no degree                             918
#
#     median_weekly_earnings_in_2017  median_weekly_earnings_in_2016 gender
# id
# 0                              996                             969   Male
# 1                              584                             551   Male
# 2                              797                             769   Male
# 3                              917                             896   Male
# 4                              886                             861   Male

# %%
pay_gap_by_education.dtypes
# Out:
# By education                      object
# Median weekly earnings in 2018     int64
# Median weekly earnings in 2017     int64
# Median weekly earnings in 2016     int64
# Gender                            object
# dtype: object

# %%
 # Use pd.to_numeric() method to convert the datatype of the Amount column
pay_gap_by_education['median_weekly_earnings_in_2018'] = pd.to_numeric(pay_gap_by_education['median_weekly_earnings_in_2018'])

# %%
list(pay_gap_by_education.columns)
# Out:
# ['education_level',
#  'median_weekly_earnings_in_2018',
#  'median_weekly_earnings_in_2017',
#  'median_weekly_earnings_in_2016',
#  'gender']

# %%
#engine.table_names()
metadata = MetaData()
metadata.reflect(bind=engine)
print(metadata.tables)
# Out:
# immutabledict({'pay_gap_by_country': Table('pay_gap_by_country', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_country>, primary_key=True, nullable=False), Column('country', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('latitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('longitude', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('sex', VARCHAR(length=20), table=<pay_gap_by_country>, nullable=False), Column('occupation', VARCHAR(length=50), table=<pay_gap_by_country>, nullable=False), Column('currency', TEXT(), table=<pay_gap_by_country>, nullable=False), Column('survey', TEXT(), table=<pay_gap_by_country>), Column('type_of_source', TEXT(), table=<pay_gap_by_country>), Column('year_2016_earnings', INTEGER(), table=<pay_gap_by_country>), schema=None), 'pay_by_race': Table('pay_by_race', MetaData(bind=None), Column('id', BIGINT(), table=<pay_by_race>), Column('categoryindex', TEXT(), table=<pay_by_race>), Column('category', TEXT(), table=<pay_by_race>), Column('total_workers', BIGINT(), table=<pay_by_race>), Column('median_weekly_earnings', BIGINT(), table=<pay_by_race>), Column('year', BIGINT(), table=<pay_by_race>), schema=None), 'pay_by_country': Table('pay_by_country', MetaData(bind=None), Column('id', BIGINT(), table=<pay_by_country>), Column('latitude', DOUBLE_PRECISION(precision=53), table=<pay_by_country>), Column('longitude', DOUBLE_PRECISION(precision=53), table=<pay_by_country>), Column('country', TEXT(), table=<pay_by_country>), Column('sex', TEXT(), table=<pay_by_country>), Column('occupation', TEXT(), table=<pay_by_country>), Column('currency', TEXT(), table=<pay_by_country>), Column('survey', TEXT(), table=<pay_by_country>), Column('type_of_source', TEXT(), table=<pay_by_country>), Column('year_2016_earnings', BIGINT(), table=<pay_by_country>), schema=None), 'pay_gap_by_race': Table('pay_gap_by_race', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_race>, primary_key=True, nullable=False), Column('categoryindex', VARCHAR(length=50), table=<pay_gap_by_race>, nullable=False), Column('category', VARCHAR(length=50), table=<pay_gap_by_race>), Column('total_workers', INTEGER(), table=<pay_gap_by_race>), Column('median_weekly_earnings', INTEGER(), table=<pay_gap_by_race>), Column('year', INTEGER(), table=<pay_gap_by_race>), schema=None), 'pay_gap_by_education': Table('pay_gap_by_education', MetaData(bind=None), Column('id', INTEGER(), table=<pay_gap_by_education>, primary_key=True, nullable=False), Column('education_level', VARCHAR(length=50), table=<pay_gap_by_education>, nullable=False), Column('median_weekly_earnings_in_2018', INTEGER(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2017', INTEGER(), table=<pay_gap_by_education>), Column('median_weekly_earnings_in_2016', INTEGER(), table=<pay_gap_by_education>), Column('gender', VARCHAR(length=50), table=<pay_gap_by_education>), schema=None)})

# %%
pay_gap_by_education.to_sql(name='pay_gap_by_education', con=engine, if_exists='append', index=True)
